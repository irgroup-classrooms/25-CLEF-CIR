# %%
import yaml
import os
import pyterrier as pt
import pandas as pd
import json
from sqlalchemy import create_engine

# %%
BASE_PATH = "/home/jovyan/work/datasets/LongEval-Web"

with open(BASE_PATH + "/metadata.yml", "r") as yamlfile:
    config = yaml.load(yamlfile, Loader=yaml.FullLoader)

# %%
# Definiere die Spaltennamen
column_names = ["QueryID", "Spalte2", "DocID", "Relevanz"]

# Qrels-Dateien laden
qrels1 = pd.read_csv("/home/jovyan/work/datasets/LongEval-Web/release_2025_p1/French/LongEval Train Collection/qrels/2023-02_fr/qrels_processed.txt", sep=" ", header=None, names=column_names)

# Liste von QueryIDs, die verarbeitet werden sollen
query_ids = list(range(1, 82000))

# Dictionary zur Speicherung der relevanten DocIDs für jede QueryID
query_doc_map = {}

# Schleife über alle QueryIDs
for query_id in query_ids:
    # Filtere nach der aktuellen QueryID und relevanten Dokumenten (Relevanz > 0)
    qrels_qid = qrels1[(qrels1["QueryID"] == query_id) & (qrels1["Relevanz"] > 0)]
    
    # Speichere die relevanten DocIDs in einer Liste mit "doc"-Präfix
    formatted_docs = ["doc" + str(doc_id) for doc_id in qrels_qid["DocID"].tolist()]
    
    # Wenn die Liste nicht leer ist, speichere das Ergebnis im Dictionary
    if formatted_docs:
        query_doc_map[query_id] = formatted_docs

# Ausgabe der Ergebnisse
for qid, docs in query_doc_map.items():
    print(f"Relevante DocIDs für Query {qid}: {docs}")
# Out:
# Relevante DocIDs für Query 3: ['doc1646118']
# Relevante DocIDs für Query 8: ['doc19754']
# Relevante DocIDs für Query 12: ['doc20559', 'doc20930', 'doc22877']
# Relevante DocIDs für Query 18: ['doc19416', 'doc18882']
# Relevante DocIDs für Query 19: ['doc8323']
# Relevante DocIDs für Query 20: ['doc1716', 'doc4311']
# Relevante DocIDs für Query 23: ['doc2916388']
# Relevante DocIDs für Query 24: ['doc8592']
# Relevante DocIDs für Query 26: ['doc3410422', 'doc3344995']
# Relevante DocIDs für Query 27: ['doc2588', 'doc3246', 'doc23258']
# Relevante DocIDs für Query 28: ['doc16256', 'doc13703']
# Relevante DocIDs für Query 29: ['doc26747', 'doc2869393', 'doc2876151', 'doc1701907']
# Relevante DocIDs für Query 30: ['doc2874670', 'doc1644643', 'doc955', 'doc23020', 'doc2909443', 'doc1706936']
# Relevante DocIDs für Query 32: ['doc2904587', 'doc1688288']
# Relevante DocIDs für Query 33: ['doc1684120']
# Relevante DocIDs für Query 41: ['doc21116']
# Relevante DocIDs für Query 42: ['doc21520']
# Relevante DocIDs für Query 43: ['doc15389', 'doc1698']
# Relevante DocIDs für Query 44: ['doc23717']
# Relevante DocIDs für Query 45: ['doc4985', 'doc24032', 'doc2908659']
# Relevante DocIDs für Query 46: ['doc25901']
# Relevante DocIDs für Query 49: ['doc1695753', 'doc2868235']
# Relevante DocIDs für Query 50: ['doc2905131']
# Relevante DocIDs für Query 51: ['doc236']
# Relevante DocIDs für Query 53: ['doc21337']
# Relevante DocIDs für Query 54: ['doc19445']
# Relevante DocIDs für Query 56: ['doc1367', 'doc2651']
# Relevante DocIDs für Query 58: ['doc1614518', 'doc1593606', 'doc2874983']
# Relevante DocIDs für Query 60: ['doc1611735']
# Relevante DocIDs für Query 62: ['doc4850', 'doc9584']
# Relevante DocIDs für Query 64: ['doc14843']
# Relevante DocIDs für Query 68: ['doc21772']
# Relevante DocIDs für Query 70: ['doc1589698']
# Relevante DocIDs für Query 71: ['doc1644703']
# Relevante DocIDs für Query 76: ['doc1685581']
# Relevante DocIDs für Query 81: ['doc1643098']
# Relevante DocIDs für Query 84: ['doc23562']
# Relevante DocIDs für Query 85: ['doc1925', 'doc22776', 'doc14125', 'doc275']
# Relevante DocIDs für Query 89: ['doc21285']
# Relevante DocIDs für Query 91: ['doc9339']
# Relevante DocIDs für Query 93: ['doc19636']
# Relevante DocIDs für Query 95: ['doc11798', 'doc1471']
# Relevante DocIDs für Query 98: ['doc1689652']
# Relevante DocIDs für Query 99: ['doc24218']
# Relevante DocIDs für Query 100: ['doc1504']
# Relevante DocIDs für Query 103: ['doc11417']
# Relevante DocIDs für Query 107: ['doc15023', 'doc3398320']
# Relevante DocIDs für Query 108: ['doc3005']
# Relevante DocIDs für Query 109: ['doc5600', 'doc5527']
# Relevante DocIDs für Query 111: ['doc7037', 'doc1321', 'doc1367']
# Relevante DocIDs für Query 112: ['doc28191', 'doc1678789']
# Relevante DocIDs für Query 113: ['doc1590860', 'doc1592633', 'doc3630']
# Relevante DocIDs für Query 114: ['doc1596769']
# Relevante DocIDs für Query 115: ['doc2914386', 'doc2021718']
# Relevante DocIDs für Query 116: ['doc1597381', 'doc21345']
# Relevante DocIDs für Query 117: ['doc6593', 'doc10011']
# Relevante DocIDs für Query 118: ['doc15773']
# Relevante DocIDs für Query 120: ['doc1592139', 'doc7113', 'doc3395', 'doc21843']
# Relevante DocIDs für Query 121: ['doc28989', 'doc18712']
# Relevante DocIDs für Query 123: ['doc25080']
# Relevante DocIDs für Query 124: ['doc17586']
# Relevante DocIDs für Query 132: ['doc12433']
# Relevante DocIDs für Query 133: ['doc12433']
# Relevante DocIDs für Query 136: ['doc3428247', 'doc3359143']
# Relevante DocIDs für Query 139: ['doc2861584']
# Relevante DocIDs für Query 140: ['doc1706647', 'doc1593851']
# Relevante DocIDs für Query 146: ['doc1597750']
# Relevante DocIDs für Query 148: ['doc1675809', 'doc1706856']
# Relevante DocIDs für Query 150: ['doc1646450']
# Relevante DocIDs für Query 152: ['doc1646038', 'doc1201']
# Relevante DocIDs für Query 153: ['doc2860280']
# Relevante DocIDs für Query 157: ['doc10189']
# Relevante DocIDs für Query 158: ['doc19830']
# Relevante DocIDs für Query 164: ['doc16256']
# Relevante DocIDs für Query 166: ['doc25513', 'doc13601']
# Relevante DocIDs für Query 168: ['doc1597574', 'doc1593593', 'doc2907447', 'doc1591067']
# Relevante DocIDs für Query 172: ['doc2360']
# Relevante DocIDs für Query 173: ['doc4739']
# Relevante DocIDs für Query 181: ['doc4739']
# Relevante DocIDs für Query 192: ['doc1611158']
# Relevante DocIDs für Query 196: ['doc17553', 'doc1700158']
# Relevante DocIDs für Query 199: ['doc1611158']
# Relevante DocIDs für Query 202: ['doc1682235', 'doc3352508', 'doc2898626']
# Relevante DocIDs für Query 219: ['doc13027']
# Relevante DocIDs für Query 220: ['doc2867581', 'doc1593363', 'doc1612718']
# Relevante DocIDs für Query 221: ['doc1595886', 'doc8043', 'doc10167']
# Relevante DocIDs für Query 222: ['doc2874815']
# Relevante DocIDs für Query 224: ['doc1676341']
# Relevante DocIDs für Query 227: ['doc9419']
# Relevante DocIDs für Query 230: ['doc1693655']
# Relevante DocIDs für Query 236: ['doc10018']
# Relevante DocIDs für Query 237: ['doc21279']
# Relevante DocIDs für Query 238: ['doc3358806', 'doc3355620', 'doc3361855']
# Relevante DocIDs für Query 243: ['doc1672632', 'doc1702754']
# Relevante DocIDs für Query 249: ['doc2876939']
# Relevante DocIDs für Query 250: ['doc13697']
# Relevante DocIDs für Query 252: ['doc4296', 'doc16872', 'doc24677', 'doc9475', 'doc9880']
# Relevante DocIDs für Query 253: ['doc3348333']
# Relevante DocIDs für Query 259: ['doc1677863']
# Relevante DocIDs für Query 264: ['doc3397134', 'doc3392890', 'doc3422526', 'doc3421752']
# Relevante DocIDs für Query 266: ['doc29188']
# Relevante DocIDs für Query 267: ['doc18221', 'doc19724']
# Relevante DocIDs für Query 271: ['doc2900668', 'doc16127', 'doc1644210', 'doc2606', 'doc3346130']
# Relevante DocIDs für Query 273: ['doc25769', 'doc2867564', 'doc11236', 'doc1688203']
# Relevante DocIDs für Query 274: ['doc17195', 'doc25769', 'doc557', 'doc1689425', 'doc1688203']
# Relevante DocIDs für Query 285: ['doc25441']
# Relevante DocIDs für Query 286: ['doc142']
# Relevante DocIDs für Query 294: ['doc2897332']
# Relevante DocIDs für Query 295: ['doc21307']
# Relevante DocIDs für Query 299: ['doc1687486']
# Relevante DocIDs für Query 303: ['doc2875562', 'doc2859567', 'doc2900858']
# Relevante DocIDs für Query 305: ['doc15875']
# Relevante DocIDs für Query 306: ['doc15875', 'doc215', 'doc14148', 'doc14945']
# Relevante DocIDs für Query 308: ['doc2896816']
# Relevante DocIDs für Query 310: ['doc1687297']
# Relevante DocIDs für Query 313: ['doc1697167', 'doc1697180']
# Relevante DocIDs für Query 317: ['doc1596412', 'doc1590654']
# Relevante DocIDs für Query 323: ['doc1591143']
# Relevante DocIDs für Query 325: ['doc7496']
# Relevante DocIDs für Query 326: ['doc22646']
# Relevante DocIDs für Query 328: ['doc15861', 'doc7066', 'doc1999']
# Relevante DocIDs für Query 329: ['doc1682173']
# Relevante DocIDs für Query 332: ['doc1692833', 'doc1681443']
# Relevante DocIDs für Query 333: ['doc7066']
# Relevante DocIDs für Query 334: ['doc2860903']
# Relevante DocIDs für Query 335: ['doc1695942']
# Relevante DocIDs für Query 337: ['doc21240', 'doc1796']
# Relevante DocIDs für Query 338: ['doc2877599']
# Relevante DocIDs für Query 341: ['doc21284']
# Relevante DocIDs für Query 343: ['doc21284']
# Relevante DocIDs für Query 346: ['doc1672484']
# Relevante DocIDs für Query 347: ['doc1695383', 'doc1691966']
# Relevante DocIDs für Query 348: ['doc1610992', 'doc1616581']
# Relevante DocIDs für Query 350: ['doc1676374']
# Relevante DocIDs für Query 353: ['doc1613691']
# Relevante DocIDs für Query 355: ['doc14114']
# Relevante DocIDs für Query 357: ['doc16578']
# Relevante DocIDs für Query 358: ['doc1640434', 'doc22442', 'doc2911536', 'doc4259']
# Relevante DocIDs für Query 362: ['doc6381']
# Relevante DocIDs für Query 363: ['doc24675']
# Relevante DocIDs für Query 366: ['doc1970']
# Relevante DocIDs für Query 370: ['doc14497']
# Relevante DocIDs für Query 371: ['doc6032', 'doc111080']
# Relevante DocIDs für Query 374: ['doc1687046', 'doc1701418']
# Relevante DocIDs für Query 376: ['doc3357561']
# Relevante DocIDs für Query 377: ['doc1687927', 'doc3403903', 'doc3380117', 'doc3351593']
# Relevante DocIDs für Query 381: ['doc28161']
# Relevante DocIDs für Query 382: ['doc1680583', 'doc2902719', 'doc1674286']
# Relevante DocIDs für Query 384: ['doc2903298', 'doc1671961']
# Relevante DocIDs für Query 392: ['doc1682357']
# Relevante DocIDs für Query 393: ['doc1695319', 'doc1596709', 'doc1615724', 'doc2897393']
# Relevante DocIDs für Query 395: ['doc1688963', 'doc5003', 'doc1687454', 'doc15663']
# Relevante DocIDs für Query 396: ['doc1705249', 'doc1703177']
# Relevante DocIDs für Query 399: ['doc1592135']
# Relevante DocIDs für Query 402: ['doc6100']
# Relevante DocIDs für Query 404: ['doc2911822']
# Relevante DocIDs für Query 407: ['doc2864912']
# Relevante DocIDs für Query 410: ['doc26758', 'doc22507', 'doc1597789']
# Relevante DocIDs für Query 411: ['doc17381']
# Relevante DocIDs für Query 416: ['doc1691503']
# Relevante DocIDs für Query 418: ['doc7568']
# Relevante DocIDs für Query 420: ['doc4903']
# Relevante DocIDs für Query 423: ['doc1697655']
# Relevante DocIDs für Query 432: ['doc1591250', 'doc1689352', 'doc2913949', 'doc2903774']
# Relevante DocIDs für Query 433: ['doc1671717']
# Relevante DocIDs für Query 437: ['doc2910257', 'doc1613551']
# Relevante DocIDs für Query 438: ['doc17423']
# Relevante DocIDs für Query 440: ['doc8644']
# Relevante DocIDs für Query 442: ['doc2872021']
# Relevante DocIDs für Query 450: ['doc1674123']
# Relevante DocIDs für Query 451: ['doc1641205', 'doc2901741']
# Relevante DocIDs für Query 452: ['doc1686463', 'doc1596410']
# Relevante DocIDs für Query 454: ['doc1692715']
# Relevante DocIDs für Query 456: ['doc3432481']
# Relevante DocIDs für Query 457: ['doc1705947', 'doc1690995']
# Relevante DocIDs für Query 459: ['doc2523']
# Relevante DocIDs für Query 461: ['doc2902203']
# Relevante DocIDs für Query 463: ['doc29079', 'doc10570']
# Relevante DocIDs für Query 466: ['doc2907717']
# Relevante DocIDs für Query 467: ['doc1683759']
# Relevante DocIDs für Query 469: ['doc2859674']
# Relevante DocIDs für Query 472: ['doc11702', 'doc310']
# Relevante DocIDs für Query 479: ['doc29079']
# Relevante DocIDs für Query 483: ['doc1677668']
# Relevante DocIDs für Query 485: ['doc1701097']
# Relevante DocIDs für Query 490: ['doc1640859']
# Relevante DocIDs für Query 491: ['doc1678260']
# Relevante DocIDs für Query 494: ['doc1707947', 'doc3365057']
# Relevante DocIDs für Query 500: ['doc1613602']
# Relevante DocIDs für Query 504: ['doc13317']
# Relevante DocIDs für Query 508: ['doc1673237']
# Relevante DocIDs für Query 509: ['doc1612443']
# Relevante DocIDs für Query 510: ['doc1673548', 'doc1699037']
# Relevante DocIDs für Query 512: ['doc14040']
# Relevante DocIDs für Query 519: ['doc1675581']
# Relevante DocIDs für Query 522: ['doc1958']
# Relevante DocIDs für Query 531: ['doc110']
# Relevante DocIDs für Query 532: ['doc7930', 'doc1698273', 'doc10659', 'doc10605']
# Relevante DocIDs für Query 533: ['doc10659', 'doc6732', 'doc1706647', 'doc1698273', 'doc1706097', 'doc1693925']
# Relevante DocIDs für Query 534: ['doc1701533', 'doc1706647', 'doc1704337']
# Relevante DocIDs für Query 535: ['doc1676599', 'doc1675229']
# Relevante DocIDs für Query 537: ['doc1674119', 'doc2862850', 'doc1673230']
# Relevante DocIDs für Query 540: ['doc18379', 'doc1595541', 'doc10303', 'doc1697899']
# Relevante DocIDs für Query 543: ['doc9551', 'doc27993']
# Relevante DocIDs für Query 544: ['doc1694811']
# Relevante DocIDs für Query 547: ['doc27227']
# Relevante DocIDs für Query 548: ['doc3958', 'doc1561', 'doc27227', 'doc28975']
# Relevante DocIDs für Query 557: ['doc1679683']
# Relevante DocIDs für Query 565: ['doc11334', 'doc25941']
# Relevante DocIDs für Query 571: ['doc1611468']
# Relevante DocIDs für Query 572: ['doc3406247', 'doc3410330', 'doc3400356']
# Relevante DocIDs für Query 578: ['doc13984']
# Relevante DocIDs für Query 585: ['doc1694611']
# Relevante DocIDs für Query 587: ['doc1614131']
# Relevante DocIDs für Query 588: ['doc25325']
# Relevante DocIDs für Query 595: ['doc17774']
# Relevante DocIDs für Query 603: ['doc11599', 'doc1679402']
# Relevante DocIDs für Query 604: ['doc1687281']
# Relevante DocIDs für Query 605: ['doc2863205']
# Relevante DocIDs für Query 607: ['doc3582']
# Relevante DocIDs für Query 608: ['doc3386721', 'doc3392352']
# Relevante DocIDs für Query 609: ['doc3958', 'doc2861389', 'doc7790', 'doc3679', 'doc18922', 'doc24236']
# Relevante DocIDs für Query 611: ['doc23310', 'doc1164', 'doc5407']
# Relevante DocIDs für Query 613: ['doc2875317']
# Relevante DocIDs für Query 614: ['doc2860776']
# Relevante DocIDs für Query 615: ['doc29032']
# Relevante DocIDs für Query 616: ['doc13058']
# Relevante DocIDs für Query 617: ['doc23838', 'doc13071', 'doc21571']
# Relevante DocIDs für Query 618: ['doc8591']
# Relevante DocIDs für Query 619: ['doc18048']
# Relevante DocIDs für Query 620: ['doc1591694']
# Relevante DocIDs für Query 621: ['doc10994', 'doc1681986']
# Relevante DocIDs für Query 622: ['doc22737']
# Relevante DocIDs für Query 623: ['doc5369', 'doc13123', 'doc2909948']
# Relevante DocIDs für Query 624: ['doc1671498']
# Relevante DocIDs für Query 625: ['doc15687']
# Relevante DocIDs für Query 626: ['doc15687', 'doc21163', 'doc2865341']
# Relevante DocIDs für Query 627: ['doc15687']
# Relevante DocIDs für Query 629: ['doc13153', 'doc7385']
# Relevante DocIDs für Query 636: ['doc1694858', 'doc3428223', 'doc1700538']
# Relevante DocIDs für Query 643: ['doc14758']
# Relevante DocIDs für Query 648: ['doc5806', 'doc684']
# Relevante DocIDs für Query 649: ['doc1595782', 'doc1591706', 'doc1593255']
# Relevante DocIDs für Query 651: ['doc14864']
# Relevante DocIDs für Query 653: ['doc1681646']
# Relevante DocIDs für Query 657: ['doc19724']
# Relevante DocIDs für Query 658: ['doc19724']
# Relevante DocIDs für Query 659: ['doc3864']
# Relevante DocIDs für Query 664: ['doc15667']
# Relevante DocIDs für Query 666: ['doc3363852']
# Relevante DocIDs für Query 671: ['doc3348173']
# Relevante DocIDs für Query 672: ['doc20871']
# Relevante DocIDs für Query 673: ['doc8954', 'doc7429', 'doc2010']
# Relevante DocIDs für Query 675: ['doc1641788']
# Relevante DocIDs für Query 679: ['doc1696929']
# Relevante DocIDs für Query 683: ['doc1689892']
# Relevante DocIDs für Query 684: ['doc1704260']
# Relevante DocIDs für Query 685: ['doc28256']
# Relevante DocIDs für Query 688: ['doc22426']
# Relevante DocIDs für Query 692: ['doc1596355', 'doc2910533']
# Relevante DocIDs für Query 693: ['doc1591687', 'doc2904741']
# Relevante DocIDs für Query 694: ['doc5592']
# Relevante DocIDs für Query 696: ['doc1696693', 'doc1682109']
# Relevante DocIDs für Query 699: ['doc6251', 'doc11205', 'doc7947']
# Relevante DocIDs für Query 701: ['doc22539']
# Relevante DocIDs für Query 706: ['doc22847', 'doc21926']
# Relevante DocIDs für Query 708: ['doc4176', 'doc1597668', 'doc7703']
# Relevante DocIDs für Query 713: ['doc3395280', 'doc3416740', 'doc3384210']
# Relevante DocIDs für Query 719: ['doc2136', 'doc28861']
# Relevante DocIDs für Query 720: ['doc1707265']
# Relevante DocIDs für Query 721: ['doc2910490']
# Relevante DocIDs für Query 722: ['doc1703224']
# Relevante DocIDs für Query 723: ['doc1706166']
# Relevante DocIDs für Query 726: ['doc1686522']
# Relevante DocIDs für Query 728: ['doc16029']
# Relevante DocIDs für Query 729: ['doc27126', 'doc16029', 'doc785']
# Relevante DocIDs für Query 733: ['doc1591878', 'doc1593097']
# Relevante DocIDs für Query 736: ['doc1679932']
# Relevante DocIDs für Query 740: ['doc25735', 'doc19053']
# Relevante DocIDs für Query 742: ['doc1592756']
# Relevante DocIDs für Query 745: ['doc1597721']
# Relevante DocIDs für Query 747: ['doc25323', 'doc9358', 'doc15315']
# Relevante DocIDs für Query 748: ['doc16599', 'doc2879715', 'doc5618']
# Relevante DocIDs für Query 750: ['doc21284']
# Relevante DocIDs für Query 751: ['doc1685816']
# Relevante DocIDs für Query 752: ['doc4903']
# Relevante DocIDs für Query 753: ['doc4903']
# Relevante DocIDs für Query 755: ['doc4903']
# Relevante DocIDs für Query 756: ['doc1090']
# Relevante DocIDs für Query 760: ['doc3378285', 'doc6988']
# Relevante DocIDs für Query 763: ['doc11105', 'doc2904186', 'doc3359852']
# Relevante DocIDs für Query 765: ['doc2904186', 'doc3359852']
# Relevante DocIDs für Query 770: ['doc1595967', 'doc25738']
# Relevante DocIDs für Query 774: ['doc1679489', 'doc9038', 'doc1707719']
# Relevante DocIDs für Query 783: ['doc1705726', 'doc2904919', 'doc1594268']
# Relevante DocIDs für Query 784: ['doc1596946', 'doc1594268', 'doc28484']
# Relevante DocIDs für Query 785: ['doc13287', 'doc2898010', 'doc1598197']
# Relevante DocIDs für Query 789: ['doc28861']
# Relevante DocIDs für Query 790: ['doc2404', 'doc23073']
# Relevante DocIDs für Query 795: ['doc6689']
# Relevante DocIDs für Query 801: ['doc1674056']
# Relevante DocIDs für Query 802: ['doc1596737']
# Relevante DocIDs für Query 803: ['doc7688']
# Relevante DocIDs für Query 804: ['doc22774', 'doc24519', 'doc1653']
# Relevante DocIDs für Query 807: ['doc13030', 'doc7291', 'doc2735']
# Relevante DocIDs für Query 810: ['doc1687269']
# Relevante DocIDs für Query 813: ['doc9626']
# Relevante DocIDs für Query 820: ['doc3358653']
# Relevante DocIDs für Query 822: ['doc3376914', 'doc3347293', 'doc3350321', 'doc3344991']
# Relevante DocIDs für Query 825: ['doc22693']
# Relevante DocIDs für Query 827: ['doc13693', 'doc2919129']
# Relevante DocIDs für Query 830: ['doc14233', 'doc16045', 'doc29238', 'doc2921599', 'doc28447']
# Relevante DocIDs für Query 831: ['doc6549', 'doc22604', 'doc22668', 'doc16551']
# Relevante DocIDs für Query 832: ['doc1592207', 'doc1644018']
# Relevante DocIDs für Query 837: ['doc1693351']
# Relevante DocIDs für Query 842: ['doc3364245', 'doc2917354', 'doc2918664', 'doc3363468']
# Relevante DocIDs für Query 843: ['doc3417598', 'doc3429073', 'doc2874125', 'doc1592712']
# Relevante DocIDs für Query 850: ['doc1671641', 'doc2872368']
# Relevante DocIDs für Query 851: ['doc3387308']
# Relevante DocIDs für Query 852: ['doc1687131']
# Relevante DocIDs für Query 855: ['doc1700494']
# Relevante DocIDs für Query 856: ['doc2915362']
# Relevante DocIDs für Query 857: ['doc1697671']
# Relevante DocIDs für Query 858: ['doc1676477']
# Relevante DocIDs für Query 859: ['doc1698541']
# Relevante DocIDs für Query 860: ['doc1685742']
# Relevante DocIDs für Query 861: ['doc1673463']
# Relevante DocIDs für Query 864: ['doc2913050']
# Relevante DocIDs für Query 867: ['doc2916280']
# Relevante DocIDs für Query 868: ['doc2901590']
# Relevante DocIDs für Query 869: ['doc1701592']
# Relevante DocIDs für Query 873: ['doc1691135']
# Relevante DocIDs für Query 874: ['doc28195']
# Relevante DocIDs für Query 876: ['doc14675', 'doc26305']
# Relevante DocIDs für Query 877: ['doc10385', 'doc19505', 'doc8851']
# Relevante DocIDs für Query 886: ['doc1684142', 'doc1058', 'doc9555']
# Relevante DocIDs für Query 887: ['doc2919417']
# Relevante DocIDs für Query 889: ['doc1683335']
# Relevante DocIDs für Query 890: ['doc25521']
# Relevante DocIDs für Query 893: ['doc15672']
# Relevante DocIDs für Query 896: ['doc2910645']
# Relevante DocIDs für Query 897: ['doc25521']
# Relevante DocIDs für Query 900: ['doc1697218', 'doc2910342']
# Relevante DocIDs für Query 905: ['doc28529', 'doc9990']
# Relevante DocIDs für Query 906: ['doc9990', 'doc28529']
# Relevante DocIDs für Query 907: ['doc18639']
# Relevante DocIDs für Query 908: ['doc15672']
# Relevante DocIDs für Query 910: ['doc1683335', 'doc1683750']
# Relevante DocIDs für Query 913: ['doc1685217']
# Relevante DocIDs für Query 914: ['doc1590283']
# Relevante DocIDs für Query 916: ['doc3350667']
# Relevante DocIDs für Query 919: ['doc12017']
# Relevante DocIDs für Query 923: ['doc23058']
# Relevante DocIDs für Query 930: ['doc1616572']
# Relevante DocIDs für Query 934: ['doc11400']
# Relevante DocIDs für Query 935: ['doc1593282', 'doc1591617', 'doc1595865', 'doc1591720']
# Relevante DocIDs für Query 936: ['doc21047']
# Relevante DocIDs für Query 938: ['doc6089']
# Relevante DocIDs für Query 940: ['doc13860', 'doc1670594', 'doc24741', 'doc1598162']
# Relevante DocIDs für Query 941: ['doc1677632', 'doc1702374']
# Relevante DocIDs für Query 942: ['doc14631']
# Relevante DocIDs für Query 950: ['doc3343575', 'doc1695047', 'doc3408015']
# Relevante DocIDs für Query 952: ['doc14999', 'doc15875', 'doc17667', 'doc17444']
# Relevante DocIDs für Query 954: ['doc2286', 'doc15875', 'doc5325', 'doc17444']
# Relevante DocIDs für Query 956: ['doc3349914']
# Relevante DocIDs für Query 957: ['doc8612']
# Relevante DocIDs für Query 959: ['doc12400']
# Relevante DocIDs für Query 961: ['doc1684036', 'doc12400']
# Relevante DocIDs für Query 963: ['doc12400']
# Relevante DocIDs für Query 964: ['doc1646070', 'doc8617', 'doc24741', 'doc12400', 'doc2912698']
# Relevante DocIDs für Query 965: ['doc12400']
# Relevante DocIDs für Query 967: ['doc18733']
# Relevante DocIDs für Query 969: ['doc10078']
# Relevante DocIDs für Query 972: ['doc12400']
# Relevante DocIDs für Query 973: ['doc14999', 'doc15875']
# Relevante DocIDs für Query 976: ['doc12400']
# Relevante DocIDs für Query 977: ['doc29213']
# Relevante DocIDs für Query 981: ['doc20631']
# Relevante DocIDs für Query 982: ['doc20631']
# Relevante DocIDs für Query 984: ['doc10613', 'doc12118', 'doc13102']
# Relevante DocIDs für Query 986: ['doc24460']
# Relevante DocIDs für Query 990: ['doc18673']
# Relevante DocIDs für Query 992: ['doc13560']
# Relevante DocIDs für Query 996: ['doc1406', 'doc6968']
# Relevante DocIDs für Query 1000: ['doc7496']
# Relevante DocIDs für Query 1006: ['doc2919184', 'doc11595']
# Relevante DocIDs für Query 1007: ['doc1692572']
# Relevante DocIDs für Query 1009: ['doc12400']
# Relevante DocIDs für Query 1016: ['doc2864']
# Relevante DocIDs für Query 1017: ['doc12607', 'doc25421', 'doc8511']
# Relevante DocIDs für Query 1018: ['doc1643196', 'doc2908973']
# Relevante DocIDs für Query 1019: ['doc21440', 'doc4850']
# Relevante DocIDs für Query 1021: ['doc8519', 'doc3258']
# Relevante DocIDs für Query 1022: ['doc1644880']
# Relevante DocIDs für Query 1023: ['doc1405']
# Relevante DocIDs für Query 1026: ['doc11156', 'doc2760']
# Relevante DocIDs für Query 1027: ['doc1661']
# Relevante DocIDs für Query 1028: ['doc3258', 'doc8519', 'doc2907653']
# Relevante DocIDs für Query 1029: ['doc7268']
# Relevante DocIDs für Query 1033: ['doc955', 'doc1644643', 'doc2909443']
# Relevante DocIDs für Query 1039: ['doc21778']
# Relevante DocIDs für Query 1042: ['doc26639']
# Relevante DocIDs für Query 1045: ['doc21153', 'doc19276']
# Relevante DocIDs für Query 1047: ['doc20164']
# Relevante DocIDs für Query 1050: ['doc3928', 'doc1591823']
# Relevante DocIDs für Query 1052: ['doc2863591']
# Relevante DocIDs für Query 1053: ['doc9817']
# Relevante DocIDs für Query 1054: ['doc2912507', 'doc1643906', 'doc25396']
# Relevante DocIDs für Query 1055: ['doc1696']
# Relevante DocIDs für Query 1059: ['doc17176']
# Relevante DocIDs für Query 1060: ['doc19489']
# Relevante DocIDs für Query 1061: ['doc1643653']
# Relevante DocIDs für Query 1065: ['doc29003']
# Relevante DocIDs für Query 1067: ['doc2878914']
# Relevante DocIDs für Query 1068: ['doc13708', 'doc1641360', 'doc28660']
# Relevante DocIDs für Query 1070: ['doc24975']
# Relevante DocIDs für Query 1071: ['doc24975']
# Relevante DocIDs für Query 1072: ['doc4172']
# Relevante DocIDs für Query 1075: ['doc2859']
# Relevante DocIDs für Query 1079: ['doc2381']
# Relevante DocIDs für Query 1080: ['doc1841']
# Relevante DocIDs für Query 1081: ['doc23355', 'doc23774']
# Relevante DocIDs für Query 1084: ['doc9551']
# Relevante DocIDs für Query 1085: ['doc29000', 'doc2874657', 'doc3118', 'doc28208']
# Relevante DocIDs für Query 1092: ['doc1644880']
# Relevante DocIDs für Query 1098: ['doc14256', 'doc20627', 'doc17932']
# Relevante DocIDs für Query 1099: ['doc22502', 'doc19137']
# Relevante DocIDs für Query 1102: ['doc10482']
# Relevante DocIDs für Query 1103: ['doc10482']
# Relevante DocIDs für Query 1106: ['doc2906610', 'doc1699730']
# Relevante DocIDs für Query 1109: ['doc6678', 'doc20089']
# Relevante DocIDs für Query 1110: ['doc20089']
# Relevante DocIDs für Query 1115: ['doc3415511']
# Relevante DocIDs für Query 1120: ['doc19337', 'doc26750']
# Relevante DocIDs für Query 1123: ['doc23835', 'doc13626']
# Relevante DocIDs für Query 1128: ['doc7819']
# Relevante DocIDs für Query 1139: ['doc3108']
# Relevante DocIDs für Query 1140: ['doc19227']
# Relevante DocIDs für Query 1141: ['doc16977']
# Relevante DocIDs für Query 1145: ['doc15011', 'doc23785']
# Relevante DocIDs für Query 1147: ['doc5832']
# Relevante DocIDs für Query 1148: ['doc1778']
# Relevante DocIDs für Query 1149: ['doc1613172', 'doc1778', 'doc1593402', 'doc3387300']
# Relevante DocIDs für Query 1151: ['doc2859785']
# Relevante DocIDs für Query 1155: ['doc1683806']
# Relevante DocIDs für Query 1156: ['doc3422191', 'doc1688034', 'doc3382428', 'doc1597275']
# Relevante DocIDs für Query 1161: ['doc1684130', 'doc1699707']
# Relevante DocIDs für Query 1164: ['doc1676300', 'doc1689521', 'doc1681181']
# Relevante DocIDs für Query 1165: ['doc1610470']
# Relevante DocIDs für Query 1167: ['doc1706923']
# Relevante DocIDs für Query 1173: ['doc1402', 'doc27167', 'doc1504', 'doc23687']
# Relevante DocIDs für Query 1174: ['doc1641656']
# Relevante DocIDs für Query 1177: ['doc3580', 'doc20039']
# Relevante DocIDs für Query 1178: ['doc2914067']
# Relevante DocIDs für Query 1179: ['doc11042']
# Relevante DocIDs für Query 1182: ['doc1643282']
# Relevante DocIDs für Query 1186: ['doc8511', 'doc12607']
# Relevante DocIDs für Query 1191: ['doc12607']
# Relevante DocIDs für Query 1195: ['doc3361415', 'doc1593363', 'doc1682448']
# Relevante DocIDs für Query 1200: ['doc9974']
# Relevante DocIDs für Query 1201: ['doc1976', 'doc17121', 'doc7536']
# Relevante DocIDs für Query 1202: ['doc18631']
# Relevante DocIDs für Query 1204: ['doc1613161']
# Relevante DocIDs für Query 1205: ['doc1613161']
# Relevante DocIDs für Query 1208: ['doc2905737']
# Relevante DocIDs für Query 1209: ['doc10416']
# Relevante DocIDs für Query 1211: ['doc20541', 'doc1673045', 'doc2912671']
# Relevante DocIDs für Query 1213: ['doc1680057', 'doc1705682', 'doc3357843', 'doc12838', 'doc1694696', 'doc1670692', 'doc2896744']
# Relevante DocIDs für Query 1215: ['doc18364', 'doc1673684']
# Relevante DocIDs für Query 1216: ['doc1683949', 'doc2913587', 'doc1687171', 'doc1695891', 'doc1705700', 'doc1699279', 'doc1697336', 'doc1705782', 'doc2871746', 'doc1696003', 'doc8509', 'doc1706975']
# Relevante DocIDs für Query 1217: ['doc27653', 'doc8509', 'doc27972']
# Relevante DocIDs für Query 1219: ['doc1697533', 'doc1706105', 'doc1697069']
# Relevante DocIDs für Query 1221: ['doc1679283', 'doc1704432']
# Relevante DocIDs für Query 1227: ['doc1684145', 'doc2914931']
# Relevante DocIDs für Query 1228: ['doc1694720', 'doc1686637', 'doc2898807']
# Relevante DocIDs für Query 1229: ['doc1699166']
# Relevante DocIDs für Query 1230: ['doc2903416', 'doc1595720', 'doc1597401', 'doc1592899', 'doc2859407']
# Relevante DocIDs für Query 1232: ['doc1688670', 'doc2864941', 'doc1705060']
# Relevante DocIDs für Query 1234: ['doc1687211', 'doc1679909']
# Relevante DocIDs für Query 1238: ['doc24210']
# Relevante DocIDs für Query 1239: ['doc1703434', 'doc1707380', 'doc16232']
# Relevante DocIDs für Query 1240: ['doc27653']
# Relevante DocIDs für Query 1241: ['doc2900078']
# Relevante DocIDs für Query 1243: ['doc7193']
# Relevante DocIDs für Query 1245: ['doc20896', 'doc1702032', 'doc1701166']
# Relevante DocIDs für Query 1247: ['doc713']
# Relevante DocIDs für Query 1252: ['doc1053']
# Relevante DocIDs für Query 1257: ['doc2900839', 'doc2906159']
# Relevante DocIDs für Query 1259: ['doc2863495', 'doc1595469']
# Relevante DocIDs für Query 1263: ['doc1707210']
# Relevante DocIDs für Query 1273: ['doc14761']
# Relevante DocIDs für Query 1274: ['doc1860']
# Relevante DocIDs für Query 1279: ['doc1707231']
# Relevante DocIDs für Query 1280: ['doc42', 'doc11283', 'doc3356453']
# Relevante DocIDs für Query 1283: ['doc26170']
# Relevante DocIDs für Query 1287: ['doc11692']
# Relevante DocIDs für Query 1289: ['doc19995']
# Relevante DocIDs für Query 1290: ['doc8284', 'doc24811']
# Relevante DocIDs für Query 1292: ['doc29040']
# Relevante DocIDs für Query 1295: ['doc6359', 'doc14907']
# Relevante DocIDs für Query 1296: ['doc18143']
# Relevante DocIDs für Query 1297: ['doc10177']
# Relevante DocIDs für Query 1300: ['doc2915490', 'doc5306']
# Relevante DocIDs für Query 1301: ['doc20563']
# Relevante DocIDs für Query 1302: ['doc20563']
# Relevante DocIDs für Query 1304: ['doc27057']
# Relevante DocIDs für Query 1306: ['doc1646130']
# Relevante DocIDs für Query 1307: ['doc2654']
# Relevante DocIDs für Query 1312: ['doc1676906', 'doc1707190']
# Relevante DocIDs für Query 1314: ['doc2877082', 'doc1670906', 'doc1689374', 'doc1684716', 'doc1680991', 'doc1693747', 'doc1691703', 'doc1675708']
# Relevante DocIDs für Query 1315: ['doc4364', 'doc1694225', 'doc20896']
# Relevante DocIDs für Query 1318: ['doc1670427', 'doc1671538', 'doc20541', 'doc1682322', 'doc1678982', 'doc1679900', 'doc1676293', 'doc2870264']
# Relevante DocIDs für Query 1319: ['doc1703617', 'doc1697201', 'doc1700177', 'doc1676924', 'doc1684324', 'doc1685382']
# Relevante DocIDs für Query 1321: ['doc9187', 'doc5132']
# Relevante DocIDs für Query 1326: ['doc1688283']
# Relevante DocIDs für Query 1327: ['doc3423908']
# Relevante DocIDs für Query 1328: ['doc1702277']
# Relevante DocIDs für Query 1329: ['doc1703509', 'doc1696184']
# Relevante DocIDs für Query 1330: ['doc2920794', 'doc1680090', 'doc3364230', 'doc1707867']
# Relevante DocIDs für Query 1332: ['doc8509', 'doc1672372', 'doc1681715', 'doc1706975', 'doc21483', 'doc2913587']
# Relevante DocIDs für Query 1333: ['doc1683662']
# Relevante DocIDs für Query 1335: ['doc27972']
# Relevante DocIDs für Query 1336: ['doc1679891', 'doc1707170']
# Relevante DocIDs für Query 1338: ['doc8509']
# Relevante DocIDs für Query 1339: ['doc713']
# Relevante DocIDs für Query 1342: ['doc1704336']
# Relevante DocIDs für Query 1349: ['doc901']
# Relevante DocIDs für Query 1350: ['doc2909398']
# Relevante DocIDs für Query 1352: ['doc20723']
# Relevante DocIDs für Query 1357: ['doc8897']
# Relevante DocIDs für Query 1359: ['doc27950']
# Relevante DocIDs für Query 1361: ['doc25727']
# Relevante DocIDs für Query 1362: ['doc2863453']
# Relevante DocIDs für Query 1366: ['doc1690294', 'doc2902312', 'doc1672966', 'doc1694006', 'doc3351007']
# Relevante DocIDs für Query 1367: ['doc1702220', 'doc25986']
# Relevante DocIDs für Query 1374: ['doc1672151']
# Relevante DocIDs für Query 1377: ['doc9890']
# Relevante DocIDs für Query 1378: ['doc3413187', 'doc3425738']
# Relevante DocIDs für Query 1388: ['doc1685715']
# Relevante DocIDs für Query 1391: ['doc1694353']
# Relevante DocIDs für Query 1392: ['doc2910093', 'doc17190']
# Relevante DocIDs für Query 1394: ['doc864']
# Relevante DocIDs für Query 1396: ['doc2876127']
# Relevante DocIDs für Query 1398: ['doc3360925']
# Relevante DocIDs für Query 1399: ['doc1706720', 'doc1697268', 'doc17381']
# Relevante DocIDs für Query 1406: ['doc1672484']
# Relevante DocIDs für Query 1407: ['doc1616581']
# Relevante DocIDs für Query 1412: ['doc5413']
# Relevante DocIDs für Query 1418: ['doc12609', 'doc1402']
# Relevante DocIDs für Query 1419: ['doc12609', 'doc1597472']
# Relevante DocIDs für Query 1420: ['doc28346']
# Relevante DocIDs für Query 1421: ['doc13594']
# Relevante DocIDs für Query 1433: ['doc21012']
# Relevante DocIDs für Query 1436: ['doc2903795', 'doc7141', 'doc13844']
# Relevante DocIDs für Query 1444: ['doc3347160']
# Relevante DocIDs für Query 1450: ['doc24196']
# Relevante DocIDs für Query 1452: ['doc1595360']
# Relevante DocIDs für Query 1454: ['doc7429']
# Relevante DocIDs für Query 1456: ['doc1697289', 'doc26581']
# Relevante DocIDs für Query 1461: ['doc19005', 'doc8499']
# Relevante DocIDs für Query 1464: ['doc1703963', 'doc1670737']
# Relevante DocIDs für Query 1466: ['doc9195', 'doc1645910']
# Relevante DocIDs für Query 1468: ['doc3389977', 'doc3388273']
# Relevante DocIDs für Query 1475: ['doc1686365']
# Relevante DocIDs für Query 1481: ['doc1698140']
# Relevante DocIDs für Query 1489: ['doc18413']
# Relevante DocIDs für Query 1494: ['doc21490', 'doc24496', 'doc17552', 'doc7062', 'doc26317', 'doc29147']
# Relevante DocIDs für Query 1496: ['doc1670243']
# Relevante DocIDs für Query 1498: ['doc3364753']
# Relevante DocIDs für Query 1500: ['doc1678268', 'doc1683364']
# Relevante DocIDs für Query 1504: ['doc27455']
# Relevante DocIDs für Query 1509: ['doc1769']
# Relevante DocIDs für Query 1514: ['doc1598158']
# Relevante DocIDs für Query 1515: ['doc2869443']
# Relevante DocIDs für Query 1518: ['doc1769']
# Relevante DocIDs für Query 1522: ['doc1672098']
# Relevante DocIDs für Query 1523: ['doc25917', 'doc26442', 'doc2470']
# Relevante DocIDs für Query 1524: ['doc22767', 'doc28389']
# Relevante DocIDs für Query 1525: ['doc17381', 'doc15186', 'doc1402']
# Relevante DocIDs für Query 1529: ['doc2914451', 'doc2911147']
# Relevante DocIDs für Query 1533: ['doc11956']
# Relevante DocIDs für Query 1534: ['doc3345537', 'doc3352042', 'doc2910709', 'doc2904711', 'doc8048']
# Relevante DocIDs für Query 1536: ['doc1936', 'doc16090']
# Relevante DocIDs für Query 1539: ['doc1690946', 'doc1692383']
# Relevante DocIDs für Query 1540: ['doc1481']
# Relevante DocIDs für Query 1541: ['doc8536']
# Relevante DocIDs für Query 1542: ['doc1646074', 'doc8298']
# Relevante DocIDs für Query 1543: ['doc1682589']
# Relevante DocIDs für Query 1546: ['doc10078', 'doc15875']
# Relevante DocIDs für Query 1548: ['doc22627', 'doc26639']
# Relevante DocIDs für Query 1549: ['doc26639']
# Relevante DocIDs für Query 1553: ['doc2917559', 'doc26795']
# Relevante DocIDs für Query 1555: ['doc28363']
# Relevante DocIDs für Query 1556: ['doc1645460']
# Relevante DocIDs für Query 1559: ['doc28861']
# Relevante DocIDs für Query 1560: ['doc1700718']
# Relevante DocIDs für Query 1564: ['doc1612356', 'doc2867732']
# Relevante DocIDs für Query 1565: ['doc1704538', 'doc1681217', 'doc3420542', 'doc3425821']
# Relevante DocIDs für Query 1570: ['doc1704555']
# Relevante DocIDs für Query 1572: ['doc10235', 'doc454']
# Relevante DocIDs für Query 1573: ['doc21336']
# Relevante DocIDs für Query 1578: ['doc1694966']
# Relevante DocIDs für Query 1579: ['doc1671874']
# Relevante DocIDs für Query 1582: ['doc9929']
# Relevante DocIDs für Query 1587: ['doc3362951']
# Relevante DocIDs für Query 1590: ['doc1701799']
# Relevante DocIDs für Query 1594: ['doc21159']
# Relevante DocIDs für Query 1595: ['doc713']
# Relevante DocIDs für Query 1599: ['doc8627']
# Relevante DocIDs für Query 1601: ['doc1695119']
# Relevante DocIDs für Query 1602: ['doc26176']
# Relevante DocIDs für Query 1603: ['doc1686008', 'doc1690945']
# Relevante DocIDs für Query 1605: ['doc26917']
# Relevante DocIDs für Query 1607: ['doc22426']
# Relevante DocIDs für Query 1608: ['doc3357506']
# Relevante DocIDs für Query 1611: ['doc1640893', 'doc1644275']
# Relevante DocIDs für Query 1612: ['doc23763']
# Relevante DocIDs für Query 1613: ['doc11186']
# Relevante DocIDs für Query 1615: ['doc14264']
# Relevante DocIDs für Query 1616: ['doc2866587']
# Relevante DocIDs für Query 1619: ['doc1358']
# Relevante DocIDs für Query 1627: ['doc7151']
# Relevante DocIDs für Query 1629: ['doc29132']
# Relevante DocIDs für Query 1630: ['doc26917']
# Relevante DocIDs für Query 1633: ['doc18783', 'doc8604', 'doc23031']
# Relevante DocIDs für Query 1635: ['doc2871755', 'doc8604']
# Relevante DocIDs für Query 1636: ['doc23031']
# Relevante DocIDs für Query 1637: ['doc1535', 'doc8591']
# Relevante DocIDs für Query 1639: ['doc2860903']
# Relevante DocIDs für Query 1640: ['doc1535', 'doc8591', 'doc11868']
# Relevante DocIDs für Query 1641: ['doc2862314', 'doc3413446']
# Relevante DocIDs für Query 1647: ['doc2918989']
# Relevante DocIDs für Query 1649: ['doc9229']
# Relevante DocIDs für Query 1652: ['doc1671498']
# Relevante DocIDs für Query 1653: ['doc3350017']
# Relevante DocIDs für Query 1655: ['doc10877']
# Relevante DocIDs für Query 1656: ['doc25992']
# Relevante DocIDs für Query 1657: ['doc2862120', 'doc1670666', 'doc2862165', 'doc1644447']
# Relevante DocIDs für Query 1659: ['doc22426']
# Relevante DocIDs für Query 1660: ['doc1677513']
# Relevante DocIDs für Query 1667: ['doc1614276']
# Relevante DocIDs für Query 1669: ['doc2901408', 'doc1590465', 'doc10229']
# Relevante DocIDs für Query 1672: ['doc1698185']
# Relevante DocIDs für Query 1674: ['doc16849', 'doc17803', 'doc15856', 'doc13864', 'doc13897']
# Relevante DocIDs für Query 1676: ['doc1645679']
# Relevante DocIDs für Query 1677: ['doc6643']
# Relevante DocIDs für Query 1678: ['doc1644970', 'doc19597']
# Relevante DocIDs für Query 1679: ['doc3347047', 'doc1642795', 'doc1672905']
# Relevante DocIDs für Query 1682: ['doc22874', 'doc2921842']
# Relevante DocIDs für Query 1688: ['doc2902115', 'doc28030', 'doc26109']
# Relevante DocIDs für Query 1690: ['doc1670937', 'doc2910004']
# Relevante DocIDs für Query 1692: ['doc14340', 'doc1074', 'doc21379']
# Relevante DocIDs für Query 1693: ['doc5195']
# Relevante DocIDs für Query 1694: ['doc26106', 'doc24231', 'doc3360364']
# Relevante DocIDs für Query 1700: ['doc24048', 'doc14116', 'doc15859', 'doc7792', 'doc7182']
# Relevante DocIDs für Query 1702: ['doc18390']
# Relevante DocIDs für Query 1707: ['doc3677', 'doc27155', 'doc1689439']
# Relevante DocIDs für Query 1710: ['doc3415544']
# Relevante DocIDs für Query 1712: ['doc19958']
# Relevante DocIDs für Query 1716: ['doc3264']
# Relevante DocIDs für Query 1717: ['doc9482']
# Relevante DocIDs für Query 1718: ['doc979917', 'doc2857539', 'doc1687471']
# Relevante DocIDs für Query 1722: ['doc6807', 'doc15154', 'doc19860', 'doc5751']
# Relevante DocIDs für Query 1725: ['doc1643513']
# Relevante DocIDs für Query 1726: ['doc8750']
# Relevante DocIDs für Query 1728: ['doc1033', 'doc10516']
# Relevante DocIDs für Query 1730: ['doc3355156']
# Relevante DocIDs für Query 1732: ['doc1907']
# Relevante DocIDs für Query 1734: ['doc3391573']
# Relevante DocIDs für Query 1735: ['doc3392898']
# Relevante DocIDs für Query 1740: ['doc1641627']
# Relevante DocIDs für Query 1742: ['doc13172']
# Relevante DocIDs für Query 1743: ['doc25130', 'doc2921444', 'doc18519']
# Relevante DocIDs für Query 1744: ['doc16567']
# Relevante DocIDs für Query 1745: ['doc1700403']
# Relevante DocIDs für Query 1749: ['doc14752']
# Relevante DocIDs für Query 1750: ['doc19321', 'doc1640991']
# Relevante DocIDs für Query 1751: ['doc13999']
# Relevante DocIDs für Query 1753: ['doc1643513']
# Relevante DocIDs für Query 1756: ['doc1689124', 'doc1676259']
# Relevante DocIDs für Query 1757: ['doc21461']
# Relevante DocIDs für Query 1758: ['doc1705032', 'doc1705229']
# Relevante DocIDs für Query 1760: ['doc1696892', 'doc4034', 'doc17331', 'doc1679062']
# Relevante DocIDs für Query 1761: ['doc27429', 'doc14813']
# Relevante DocIDs für Query 1762: ['doc1596594', 'doc1593798']
# Relevante DocIDs für Query 1763: ['doc19262']
# Relevante DocIDs für Query 1766: ['doc1682589', 'doc2914520', 'doc1410']
# Relevante DocIDs für Query 1768: ['doc1690492']
# Relevante DocIDs für Query 1770: ['doc2877106']
# Relevante DocIDs für Query 1772: ['doc1690042', 'doc1677688', 'doc1675681']
# Relevante DocIDs für Query 1773: ['doc2871774']
# Relevante DocIDs für Query 1774: ['doc6197', 'doc24678', 'doc5282']
# Relevante DocIDs für Query 1775: ['doc24678']
# Relevante DocIDs für Query 1779: ['doc10376', 'doc1612631', 'doc677']
# Relevante DocIDs für Query 1782: ['doc1378798']
# Relevante DocIDs für Query 1783: ['doc9626']
# Relevante DocIDs für Query 1784: ['doc1616227']
# Relevante DocIDs für Query 1785: ['doc26700', 'doc13040']
# Relevante DocIDs für Query 1786: ['doc1692913']
# Relevante DocIDs für Query 1790: ['doc1641614']
# Relevante DocIDs für Query 1791: ['doc1676289']
# Relevante DocIDs für Query 1792: ['doc11766']
# Relevante DocIDs für Query 1795: ['doc1695066']
# Relevante DocIDs für Query 1796: ['doc2866283', 'doc2867584']
# Relevante DocIDs für Query 1802: ['doc1692095']
# Relevante DocIDs für Query 1804: ['doc26507']
# Relevante DocIDs für Query 1808: ['doc1688072']
# Relevante DocIDs für Query 1811: ['doc28428']
# Relevante DocIDs für Query 1813: ['doc23078']
# Relevante DocIDs für Query 1814: ['doc2899982']
# Relevante DocIDs für Query 1815: ['doc21962', 'doc7154']
# Relevante DocIDs für Query 1822: ['doc1693572', 'doc1679075']
# Relevante DocIDs für Query 1823: ['doc1687327']
# Relevante DocIDs für Query 1825: ['doc22699']
# Relevante DocIDs für Query 1828: ['doc1230755', 'doc1699493', 'doc2901059']
# Relevante DocIDs für Query 1832: ['doc25302']
# Relevante DocIDs für Query 1835: ['doc14779']
# Relevante DocIDs für Query 1840: ['doc11729']
# Relevante DocIDs für Query 1841: ['doc19146']
# Relevante DocIDs für Query 1844: ['doc1697515']
# Relevante DocIDs für Query 1851: ['doc2873816', 'doc2909651']
# Relevante DocIDs für Query 1855: ['doc1615372']
# Relevante DocIDs für Query 1856: ['doc5397']
# Relevante DocIDs für Query 1858: ['doc1692275']
# Relevante DocIDs für Query 1864: ['doc1596017', 'doc2902199', 'doc2914898']
# Relevante DocIDs für Query 1867: ['doc1701970']
# Relevante DocIDs für Query 1871: ['doc9660', 'doc11611', 'doc3112']
# Relevante DocIDs für Query 1872: ['doc1677712', 'doc3350729']
# Relevante DocIDs für Query 1874: ['doc1686417']
# Relevante DocIDs für Query 1877: ['doc60']
# Relevante DocIDs für Query 1878: ['doc1518']
# Relevante DocIDs für Query 1885: ['doc25723']
# Relevante DocIDs für Query 1886: ['doc1676575', 'doc3346222']
# Relevante DocIDs für Query 1887: ['doc26817']
# Relevante DocIDs für Query 1888: ['doc1670092']
# Relevante DocIDs für Query 1889: ['doc15832']
# Relevante DocIDs für Query 1892: ['doc3175']
# Relevante DocIDs für Query 1893: ['doc1700983']
# Relevante DocIDs für Query 1895: ['doc620', 'doc4200']
# Relevante DocIDs für Query 1898: ['doc1596215']
# Relevante DocIDs für Query 1900: ['doc1706087']
# Relevante DocIDs für Query 1902: ['doc3862']
# Relevante DocIDs für Query 1903: ['doc14186']
# Relevante DocIDs für Query 1905: ['doc3393769', 'doc1644632', 'doc27870']
# Relevante DocIDs für Query 1906: ['doc3387060', 'doc1681056']
# Relevante DocIDs für Query 1909: ['doc17763']
# Relevante DocIDs für Query 1910: ['doc1504', 'doc27472']
# Relevante DocIDs für Query 1911: ['doc1696076']
# Relevante DocIDs für Query 1913: ['doc18092']
# Relevante DocIDs für Query 1916: ['doc20840']
# Relevante DocIDs für Query 1924: ['doc2410']
# Relevante DocIDs für Query 1925: ['doc1688503', 'doc1678875']
# Relevante DocIDs für Query 1926: ['doc1614843']
# Relevante DocIDs für Query 1927: ['doc1683310']
# Relevante DocIDs für Query 1933: ['doc1698249']
# Relevante DocIDs für Query 1934: ['doc1682826']
# Relevante DocIDs für Query 1936: ['doc10607']
# Relevante DocIDs für Query 1941: ['doc1685379']
# Relevante DocIDs für Query 1949: ['doc21994']
# Relevante DocIDs für Query 1955: ['doc7496']
# Relevante DocIDs für Query 1956: ['doc3376776', 'doc3426631']
# Relevante DocIDs für Query 1958: ['doc7496']
# Relevante DocIDs für Query 1959: ['doc1615973']
# Relevante DocIDs für Query 1960: ['doc6780', 'doc6638']
# Relevante DocIDs für Query 1961: ['doc19445']
# Relevante DocIDs für Query 1963: ['doc18043']
# Relevante DocIDs für Query 1968: ['doc1593623']
# Relevante DocIDs für Query 1972: ['doc7496']
# Relevante DocIDs für Query 1974: ['doc1616705', 'doc1610825']
# Relevante DocIDs für Query 1975: ['doc13725']
# Relevante DocIDs für Query 1977: ['doc1860']
# Relevante DocIDs für Query 1978: ['doc2898730']
# Relevante DocIDs für Query 1980: ['doc1681753']
# Relevante DocIDs für Query 1985: ['doc1670479']
# Relevante DocIDs für Query 1988: ['doc2875979']
# Relevante DocIDs für Query 1989: ['doc1679416']
# Relevante DocIDs für Query 1991: ['doc1671303']
# Relevante DocIDs für Query 1993: ['doc1684101']
# Relevante DocIDs für Query 1997: ['doc1680311']
# Relevante DocIDs für Query 1998: ['doc2896967']
# Relevante DocIDs für Query 2000: ['doc2910587']
# Relevante DocIDs für Query 2001: ['doc1596741']
# Relevante DocIDs für Query 2002: ['doc1680311']
# Relevante DocIDs für Query 2004: ['doc16062', 'doc26204']
# Relevante DocIDs für Query 2009: ['doc16725']
# Relevante DocIDs für Query 2011: ['doc12423', 'doc3639', 'doc26520']
# Relevante DocIDs für Query 2012: ['doc1590359']
# Relevante DocIDs für Query 2013: ['doc9935']
# Relevante DocIDs für Query 2014: ['doc21217', 'doc23452']
# Relevante DocIDs für Query 2015: ['doc16672']
# Relevante DocIDs für Query 2017: ['doc1190']
# Relevante DocIDs für Query 2018: ['doc1645970']
# Relevante DocIDs für Query 2021: ['doc7652']
# Relevante DocIDs für Query 2022: ['doc1485', 'doc29199']
# Relevante DocIDs für Query 2023: ['doc2877973', 'doc3251', 'doc1682336', 'doc1678177', 'doc20781', 'doc3391182', 'doc1673331', 'doc13069', 'doc639', 'doc14465', 'doc1678259']
# Relevante DocIDs für Query 2028: ['doc1611941', 'doc5709', 'doc10263']
# Relevante DocIDs für Query 2030: ['doc8362']
# Relevante DocIDs für Query 2033: ['doc2910008']
# Relevante DocIDs für Query 2034: ['doc2895']
# Relevante DocIDs für Query 2040: ['doc22297']
# Relevante DocIDs für Query 2042: ['doc1688623']
# Relevante DocIDs für Query 2043: ['doc27499', 'doc19256', 'doc2914894']
# Relevante DocIDs für Query 2045: ['doc24124']
# Relevante DocIDs für Query 2046: ['doc3412389', 'doc15651']
# Relevante DocIDs für Query 2047: ['doc19892']
# Relevante DocIDs für Query 2048: ['doc1677407']
# Relevante DocIDs für Query 2055: ['doc2908454', 'doc1705057', 'doc3359531']
# Relevante DocIDs für Query 2056: ['doc1677958', 'doc1698655', 'doc2877032', 'doc1700749', 'doc3424235']
# Relevante DocIDs für Query 2064: ['doc1684460', 'doc2909151']
# Relevante DocIDs für Query 2069: ['doc1701548']
# Relevante DocIDs für Query 2072: ['doc2900601', 'doc1597612']
# Relevante DocIDs für Query 2075: ['doc22141']
# Relevante DocIDs für Query 2079: ['doc23266']
# Relevante DocIDs für Query 2080: ['doc1706859']
# Relevante DocIDs für Query 2081: ['doc1699632']
# Relevante DocIDs für Query 2083: ['doc3362041']
# Relevante DocIDs für Query 2086: ['doc19376']
# Relevante DocIDs für Query 2087: ['doc2876220']
# Relevante DocIDs für Query 2091: ['doc27472', 'doc19056']
# Relevante DocIDs für Query 2092: ['doc215']
# Relevante DocIDs für Query 2093: ['doc27472', 'doc27685']
# Relevante DocIDs für Query 2097: ['doc27472', 'doc6089']
# Relevante DocIDs für Query 2098: ['doc1402', 'doc27472']
# Relevante DocIDs für Query 2099: ['doc27472', 'doc13021']
# Relevante DocIDs für Query 2100: ['doc3351112']
# Relevante DocIDs für Query 2105: ['doc16837', 'doc2901901', 'doc6279', 'doc1679419', 'doc11410', 'doc2906790', 'doc2914187', 'doc18161', 'doc1643729']
# Relevante DocIDs für Query 2106: ['doc1691773', 'doc18817']
# Relevante DocIDs für Query 2108: ['doc1673390']
# Relevante DocIDs für Query 2111: ['doc10157']
# Relevante DocIDs für Query 2120: ['doc1696653', 'doc1707236']
# Relevante DocIDs für Query 2122: ['doc14370']
# Relevante DocIDs für Query 2123: ['doc1693534']
# Relevante DocIDs für Query 2131: ['doc15948']
# Relevante DocIDs für Query 2133: ['doc10707']
# Relevante DocIDs für Query 2134: ['doc21010']
# Relevante DocIDs für Query 2135: ['doc9421', 'doc10707', 'doc1699735']
# Relevante DocIDs für Query 2136: ['doc7043']
# Relevante DocIDs für Query 2137: ['doc10707']
# Relevante DocIDs für Query 2141: ['doc3360074']
# Relevante DocIDs für Query 2143: ['doc1693086', 'doc1703853', 'doc6172']
# Relevante DocIDs für Query 2144: ['doc1686565', 'doc1683996']
# Relevante DocIDs für Query 2145: ['doc1677531']
# Relevante DocIDs für Query 2146: ['doc14332']
# Relevante DocIDs für Query 2147: ['doc2899194']
# Relevante DocIDs für Query 2148: ['doc24477', 'doc2921182', 'doc522', 'doc1687066']
# Relevante DocIDs für Query 2152: ['doc3358368']
# Relevante DocIDs für Query 2153: ['doc25715']
# Relevante DocIDs für Query 2155: ['doc1694306', 'doc3350131', 'doc1703548', 'doc1684195']
# Relevante DocIDs für Query 2156: ['doc15732', 'doc15102', 'doc25715']
# Relevante DocIDs für Query 2157: ['doc1707624', 'doc1701816', 'doc1684207']
# Relevante DocIDs für Query 2158: ['doc2915977', 'doc10848', 'doc22224']
# Relevante DocIDs für Query 2161: ['doc19765', 'doc15287', 'doc20865']
# Relevante DocIDs für Query 2162: ['doc1681308', 'doc2910599', 'doc2915419', 'doc2897155']
# Relevante DocIDs für Query 2164: ['doc22224', 'doc1673010']
# Relevante DocIDs für Query 2165: ['doc1700756', 'doc1706620', 'doc2909080']
# Relevante DocIDs für Query 2167: ['doc16686', 'doc16503', 'doc1675576']
# Relevante DocIDs für Query 2169: ['doc1690040']
# Relevante DocIDs für Query 2170: ['doc19203']
# Relevante DocIDs für Query 2171: ['doc1707042']
# Relevante DocIDs für Query 2174: ['doc2914437', 'doc3402634', 'doc19']
# Relevante DocIDs für Query 2175: ['doc1683569']
# Relevante DocIDs für Query 2176: ['doc24685']
# Relevante DocIDs für Query 2180: ['doc3402520', 'doc3393217']
# Relevante DocIDs für Query 2183: ['doc1682182']
# Relevante DocIDs für Query 2187: ['doc15288', 'doc3277', 'doc10650']
# Relevante DocIDs für Query 2195: ['doc2897418']
# Relevante DocIDs für Query 2196: ['doc1676636', 'doc1697610', 'doc3430204', 'doc1683466']
# Relevante DocIDs für Query 2201: ['doc1686795', 'doc20462']
# Relevante DocIDs für Query 2202: ['doc1697392']
# Relevante DocIDs für Query 2205: ['doc1689526']
# Relevante DocIDs für Query 2208: ['doc1678624']
# Relevante DocIDs für Query 2209: ['doc1685404']
# ...
# Relevante DocIDs für Query 56729: ['doc3398207']
# Relevante DocIDs für Query 56730: ['doc3354893']
# Relevante DocIDs für Query 56732: ['doc3351427']
# Relevante DocIDs für Query 56733: ['doc7521']
# Relevante DocIDs für Query 56735: ['doc6279', 'doc18161']
# Relevante DocIDs für Query 56736: ['doc3419932']
# Relevante DocIDs für Query 56738: ['doc1690569']
# Relevante DocIDs für Query 56739: ['doc3387746', 'doc3351440', 'doc3400000']
# Relevante DocIDs für Query 56740: ['doc6279']
# Relevante DocIDs für Query 56741: ['doc11142']
# Relevante DocIDs für Query 56742: ['doc3425397', 'doc3420461']
# Relevante DocIDs für Query 56744: ['doc1702754']
# Relevante DocIDs für Query 56747: ['doc1683996', 'doc2181']
# Relevante DocIDs für Query 56748: ['doc3362874', 'doc3414122', 'doc3418300', 'doc3350562']
# Relevante DocIDs für Query 56749: ['doc1017']
# Relevante DocIDs für Query 56751: ['doc5761', 'doc25026']
# Relevante DocIDs für Query 56752: ['doc18557']
# Relevante DocIDs für Query 56753: ['doc21520', 'doc1704657']
# Relevante DocIDs für Query 56754: ['doc14191', 'doc23717']
# Relevante DocIDs für Query 56755: ['doc8021']
# Relevante DocIDs für Query 56757: ['doc3355361']
# Relevante DocIDs für Query 56758: ['doc3386097']
# Relevante DocIDs für Query 56759: ['doc15875']
# Relevante DocIDs für Query 56760: ['doc3376055']
# Relevante DocIDs für Query 56762: ['doc1656']
# Relevante DocIDs für Query 56763: ['doc2014']
# Relevante DocIDs für Query 56764: ['doc2902105', 'doc23236']
# Relevante DocIDs für Query 56765: ['doc3410430', 'doc3431413', 'doc3409614']
# Relevante DocIDs für Query 56766: ['doc20896']
# Relevante DocIDs für Query 56768: ['doc3397978']
# Relevante DocIDs für Query 56769: ['doc1643268']
# Relevante DocIDs für Query 56772: ['doc1591604', 'doc1706986']
# Relevante DocIDs für Query 56773: ['doc6618']
# Relevante DocIDs für Query 56774: ['doc3419844']
# Relevante DocIDs für Query 56778: ['doc391']
# Relevante DocIDs für Query 56779: ['doc15128']
# Relevante DocIDs für Query 56780: ['doc1700557']
# Relevante DocIDs für Query 56781: ['doc1698399']
# Relevante DocIDs für Query 56783: ['doc25560']
# Relevante DocIDs für Query 56784: ['doc3378254', 'doc3407673']
# Relevante DocIDs für Query 56785: ['doc3351344']
# Relevante DocIDs für Query 56786: ['doc3384985']
# Relevante DocIDs für Query 56787: ['doc1691565']
# Relevante DocIDs für Query 56788: ['doc1006', 'doc3399706']
# Relevante DocIDs für Query 56789: ['doc3011', 'doc3360483']
# Relevante DocIDs für Query 56790: ['doc3382016']
# Relevante DocIDs für Query 56791: ['doc3420977']
# Relevante DocIDs für Query 56794: ['doc2861945']
# Relevante DocIDs für Query 56795: ['doc3434237']
# Relevante DocIDs für Query 56796: ['doc1687988', 'doc28207']
# Relevante DocIDs für Query 56798: ['doc10318']
# Relevante DocIDs für Query 56799: ['doc10318']
# Relevante DocIDs für Query 56800: ['doc3348528']
# Relevante DocIDs für Query 56801: ['doc3361547']
# Relevante DocIDs für Query 73723: ['doc2866857']
# Relevante DocIDs für Query 73729: ['doc3147']
# Relevante DocIDs für Query 73730: ['doc331']
# Relevante DocIDs für Query 73732: ['doc21153']
# Relevante DocIDs für Query 73751: ['doc1641599']
# Relevante DocIDs für Query 73753: ['doc21216']
# Relevante DocIDs für Query 73758: ['doc21153']
# Relevante DocIDs für Query 73772: ['doc1696150']
# Relevante DocIDs für Query 73780: ['doc1687297']
# Relevante DocIDs für Query 73781: ['doc1609954']
# Relevante DocIDs für Query 73791: ['doc25825']
# Relevante DocIDs für Query 73794: ['doc1641438', 'doc3427507', 'doc753', 'doc3391011']
# Relevante DocIDs für Query 73796: ['doc17019']
# Relevante DocIDs für Query 73809: ['doc7587']
# Relevante DocIDs für Query 73810: ['doc1678975', 'doc1691726', 'doc1677440']
# Relevante DocIDs für Query 73850: ['doc1644165', 'doc2908382', 'doc3432531', 'doc21504']
# Relevante DocIDs für Query 73857: ['doc1697129', 'doc1680353', 'doc1697152']
# Relevante DocIDs für Query 73860: ['doc1682265']
# Relevante DocIDs für Query 73861: ['doc17372', 'doc1610418', 'doc2905223']
# Relevante DocIDs für Query 73866: ['doc1504']
# Relevante DocIDs für Query 73873: ['doc1641599']
# Relevante DocIDs für Query 73919: ['doc2921296']
# Relevante DocIDs für Query 73925: ['doc5755', 'doc11623', 'doc26024']
# Relevante DocIDs für Query 73938: ['doc1693992']
# Relevante DocIDs für Query 73941: ['doc1596883']
# Relevante DocIDs für Query 73942: ['doc1689790', 'doc5830']
# Relevante DocIDs für Query 73943: ['doc1673951', 'doc24955']
# Relevante DocIDs für Query 73944: ['doc1674995', 'doc1682361']
# Relevante DocIDs für Query 73945: ['doc20089', 'doc7002', 'doc1616913']
# Relevante DocIDs für Query 73967: ['doc1644761', 'doc20089']
# Relevante DocIDs für Query 73972: ['doc23615']
# Relevante DocIDs für Query 73974: ['doc2914050']
# Relevante DocIDs für Query 73978: ['doc1594624']
# Relevante DocIDs für Query 73995: ['doc2915480', 'doc23204']
# Relevante DocIDs für Query 74006: ['doc1694147', 'doc1698293']
# Relevante DocIDs für Query 74008: ['doc1641229']
# Relevante DocIDs für Query 74013: ['doc1702666']
# Relevante DocIDs für Query 74016: ['doc2857957', 'doc3380649', 'doc3364068', 'doc3345892', 'doc3391614']
# Relevante DocIDs für Query 74028: ['doc25371', 'doc24179', 'doc2899446']
# Relevante DocIDs für Query 74044: ['doc12512']
# Relevante DocIDs für Query 74060: ['doc1698042', 'doc2863960']
# Relevante DocIDs für Query 74101: ['doc1683772']
# Relevante DocIDs für Query 74120: ['doc2913552']
# Relevante DocIDs für Query 74125: ['doc12433']
# Relevante DocIDs für Query 74130: ['doc2902593']
# Relevante DocIDs für Query 74142: ['doc2914380']
# Relevante DocIDs für Query 74149: ['doc1704657', 'doc21520']
# Relevante DocIDs für Query 74168: ['doc1594624', 'doc465']
# Relevante DocIDs für Query 74175: ['doc1596741']
# Relevante DocIDs für Query 74176: ['doc2910061', 'doc770', 'doc2908192']
# Relevante DocIDs für Query 74178: ['doc3377201', 'doc3430901']
# Relevante DocIDs für Query 74182: ['doc3423463']
# Relevante DocIDs für Query 74184: ['doc1595015', 'doc2897175', 'doc3380446', 'doc3398195']
# Relevante DocIDs für Query 74185: ['doc2021629', 'doc1597280']
# Relevante DocIDs für Query 74186: ['doc3344209']
# Relevante DocIDs für Query 74187: ['doc3343766']
# Relevante DocIDs für Query 74189: ['doc7066']
# Relevante DocIDs für Query 74191: ['doc1690206']
# Relevante DocIDs für Query 74192: ['doc2896235']
# Relevante DocIDs für Query 74194: ['doc2862194', 'doc7024']
# Relevante DocIDs für Query 74195: ['doc3424592']
# Relevante DocIDs für Query 74196: ['doc3350215', 'doc3360422', 'doc3355694']
# Relevante DocIDs für Query 74197: ['doc1504']
# Relevante DocIDs für Query 74198: ['doc3377785', 'doc3405379', 'doc3351635']
# Relevante DocIDs für Query 74199: ['doc3412810']
# Relevante DocIDs für Query 74445: ['doc1040', 'doc1699071', 'doc3420']
# Relevante DocIDs für Query 74447: ['doc19724', 'doc25743', 'doc11291']
# Relevante DocIDs für Query 74448: ['doc7429', 'doc14978', 'doc8954']
# Relevante DocIDs für Query 74449: ['doc1645072', 'doc1645350', 'doc15792', 'doc11728']
# Relevante DocIDs für Query 74453: ['doc2471', 'doc15385', 'doc11858', 'doc3790', 'doc5858', 'doc22674', 'doc2871044']
# Relevante DocIDs für Query 74454: ['doc27926', 'doc8612', 'doc27905']
# Relevante DocIDs für Query 74456: ['doc834', 'doc7448', 'doc7429']
# Relevante DocIDs für Query 74459: ['doc3345473', 'doc18927', 'doc2859']
# Relevante DocIDs für Query 74461: ['doc24247']
# Relevante DocIDs für Query 74465: ['doc1597248', 'doc2910235']
# Relevante DocIDs für Query 74468: ['doc3391573']
# Relevante DocIDs für Query 74474: ['doc1702754', 'doc3421749', 'doc1672632']
# Relevante DocIDs für Query 74475: ['doc17381', 'doc27472']
# Relevante DocIDs für Query 74478: ['doc10521']
# Relevante DocIDs für Query 74479: ['doc27472', 'doc22318', 'doc17381']
# Relevante DocIDs für Query 74482: ['doc1609798']
# Relevante DocIDs für Query 74487: ['doc2021798']
# Relevante DocIDs für Query 74488: ['doc8612', 'doc3363605']
# Relevante DocIDs für Query 74493: ['doc21284']
# Relevante DocIDs für Query 74495: ['doc7752']
# Relevante DocIDs für Query 74497: ['doc16943', 'doc20164', 'doc27002']
# Relevante DocIDs für Query 74498: ['doc26198']
# Relevante DocIDs für Query 74499: ['doc8612']
# Relevante DocIDs für Query 74502: ['doc713']
# Relevante DocIDs für Query 74504: ['doc14978', 'doc8954']
# Relevante DocIDs für Query 74510: ['doc15913']
# Relevante DocIDs für Query 74512: ['doc679']
# Relevante DocIDs für Query 74515: ['doc15490']
# Relevante DocIDs für Query 74524: ['doc1381']
# Relevante DocIDs für Query 74525: ['doc9483']
# Relevante DocIDs für Query 74526: ['doc21284']
# Relevante DocIDs für Query 74527: ['doc13587']
# Relevante DocIDs für Query 74528: ['doc26198']
# Relevante DocIDs für Query 74530: ['doc21778', 'doc10771']
# Relevante DocIDs für Query 74531: ['doc2921962', 'doc3393195']
# Relevante DocIDs für Query 74534: ['doc29234', 'doc21494']
# Relevante DocIDs für Query 74535: ['doc2901911', 'doc25867', 'doc29147', 'doc7062', 'doc21490', 'doc24496', 'doc17552']
# Relevante DocIDs für Query 74541: ['doc17000']
# Relevante DocIDs für Query 74542: ['doc11142']
# Relevante DocIDs für Query 74549: ['doc23010', 'doc10189']
# Relevante DocIDs für Query 74552: ['doc21284']
# Relevante DocIDs für Query 74553: ['doc2919631', 'doc10342', 'doc22130', 'doc13219']
# Relevante DocIDs für Query 74557: ['doc7429']
# Relevante DocIDs für Query 74558: ['doc208']
# Relevante DocIDs für Query 74560: ['doc1616494']
# Relevante DocIDs für Query 74562: ['doc1674464']
# Relevante DocIDs für Query 74563: ['doc2902001', 'doc18927']
# Relevante DocIDs für Query 74564: ['doc19969']
# Relevante DocIDs für Query 74568: ['doc3415544']
# Relevante DocIDs für Query 74569: ['doc3415544']
# Relevante DocIDs für Query 74570: ['doc3415544']
# Relevante DocIDs für Query 74572: ['doc10598', 'doc1694731', 'doc3364946', 'doc20758']
# Relevante DocIDs für Query 74575: ['doc18477']
# Relevante DocIDs für Query 74576: ['doc2902896']
# Relevante DocIDs für Query 74577: ['doc1677243']
# Relevante DocIDs für Query 74581: ['doc10521']
# Relevante DocIDs für Query 74582: ['doc18221']
# Relevante DocIDs für Query 74583: ['doc27249', 'doc12654', 'doc6717']
# Relevante DocIDs für Query 74585: ['doc10877']
# Relevante DocIDs für Query 74592: ['doc1641314']
# Relevante DocIDs für Query 74594: ['doc1694256']
# Relevante DocIDs für Query 74595: ['doc1594654']
# Relevante DocIDs für Query 74602: ['doc18221']
# Relevante DocIDs für Query 74604: ['doc1698980', 'doc19146']
# Relevante DocIDs für Query 74606: ['doc1694075']
# Relevante DocIDs für Query 74610: ['doc24802']
# Relevante DocIDs für Query 74611: ['doc22368', 'doc9266', 'doc12423']
# Relevante DocIDs für Query 74612: ['doc1616705', 'doc1610825']
# Relevante DocIDs für Query 74614: ['doc14171', 'doc27047']
# Relevante DocIDs für Query 74622: ['doc26198']
# Relevante DocIDs für Query 74626: ['doc7066']
# Relevante DocIDs für Query 74628: ['doc2866936', 'doc2906133']
# Relevante DocIDs für Query 74637: ['doc3423364', 'doc6221', 'doc3385005', 'doc3639']
# Relevante DocIDs für Query 74639: ['doc14999', 'doc15875']
# Relevante DocIDs für Query 74648: ['doc7259']
# Relevante DocIDs für Query 74655: ['doc8954', 'doc7448']
# Relevante DocIDs für Query 74656: ['doc7429']
# Relevante DocIDs für Query 74663: ['doc7448']
# Relevante DocIDs für Query 74664: ['doc9420']
# Relevante DocIDs für Query 74670: ['doc3415544']
# Relevante DocIDs für Query 74671: ['doc3361458', 'doc3363148']
# Relevante DocIDs für Query 74675: ['doc1592417']
# Relevante DocIDs für Query 74679: ['doc10078']
# Relevante DocIDs für Query 74684: ['doc21284']
# Relevante DocIDs für Query 74692: ['doc25086', 'doc1641821']
# Relevante DocIDs für Query 74694: ['doc1699305', 'doc1696645']
# Relevante DocIDs für Query 74696: ['doc3406204']
# Relevante DocIDs für Query 74698: ['doc3415544']
# Relevante DocIDs für Query 74700: ['doc17697']
# Relevante DocIDs für Query 74703: ['doc1640892']
# Relevante DocIDs für Query 74715: ['doc1593851']
# Relevante DocIDs für Query 74725: ['doc2912053']
# Relevante DocIDs für Query 74732: ['doc1593052', 'doc3157']
# Relevante DocIDs für Query 74746: ['doc1695859', 'doc3432345', 'doc3424464']
# Relevante DocIDs für Query 74748: ['doc1698453']
# Relevante DocIDs für Query 74753: ['doc16581']
# Relevante DocIDs für Query 74755: ['doc1695434', 'doc3346898']
# Relevante DocIDs für Query 74767: ['doc1594704', 'doc9923']
# Relevante DocIDs für Query 74772: ['doc1683417']
# Relevante DocIDs für Query 74781: ['doc23058']
# Relevante DocIDs für Query 74787: ['doc1656']
# Relevante DocIDs für Query 74793: ['doc3157']
# Relevante DocIDs für Query 74801: ['doc6445']
# Relevante DocIDs für Query 74808: ['doc3358076', 'doc3346415']
# Relevante DocIDs für Query 74829: ['doc25325']
# Relevante DocIDs für Query 74868: ['doc2872975', 'doc2866537', 'doc2876128']
# Relevante DocIDs für Query 74876: ['doc1645334']
# Relevante DocIDs für Query 74884: ['doc1680311', 'doc3359417']
# Relevante DocIDs für Query 74886: ['doc5830']
# Relevante DocIDs für Query 74891: ['doc3359969']
# Relevante DocIDs für Query 74898: ['doc1675037']
# Relevante DocIDs für Query 74902: ['doc1690358']
# Relevante DocIDs für Query 74905: ['doc1688244']
# Relevante DocIDs für Query 74912: ['doc1699812']
# Relevante DocIDs für Query 74921: ['doc2917706', 'doc3347673']
# Relevante DocIDs für Query 74925: ['doc19181']
# Relevante DocIDs für Query 74927: ['doc685']
# Relevante DocIDs für Query 74930: ['doc23058', 'doc2471']
# Relevante DocIDs für Query 74932: ['doc1695833', 'doc1690936', 'doc1703491']
# Relevante DocIDs für Query 74946: ['doc1613522']
# Relevante DocIDs für Query 74952: ['doc1705193']
# Relevante DocIDs für Query 74955: ['doc15542']
# Relevante DocIDs für Query 74957: ['doc1698235']
# Relevante DocIDs für Query 74959: ['doc1676441']
# Relevante DocIDs für Query 74964: ['doc12379']
# Relevante DocIDs für Query 74965: ['doc2021773', 'doc3429387', 'doc1685731']
# Relevante DocIDs für Query 74991: ['doc7810', 'doc7790', 'doc28975']
# Relevante DocIDs für Query 75008: ['doc1701644']
# Relevante DocIDs für Query 75025: ['doc1678546', 'doc1701644']
# Relevante DocIDs für Query 75029: ['doc2869683']
# Relevante DocIDs für Query 75030: ['doc2903510']
# Relevante DocIDs für Query 75034: ['doc2876270']
# Relevante DocIDs für Query 75036: ['doc1641821']
# Relevante DocIDs für Query 75042: ['doc2910394', 'doc2917361']
# Relevante DocIDs für Query 75055: ['doc2916966']
# Relevante DocIDs für Query 75067: ['doc1696319']
# Relevante DocIDs für Query 75068: ['doc1697093']
# Relevante DocIDs für Query 75076: ['doc3400338', 'doc3399286', 'doc3432253']
# Relevante DocIDs für Query 75077: ['doc3403951']
# Relevante DocIDs für Query 75078: ['doc1612773']
# Relevante DocIDs für Query 75079: ['doc3385919', 'doc15600', 'doc3363576']
# Relevante DocIDs für Query 75080: ['doc3417352']
# Relevante DocIDs für Query 75084: ['doc3430713']
# Relevante DocIDs für Query 75086: ['doc6558']
# Relevante DocIDs für Query 75274: ['doc14978']
# Relevante DocIDs für Query 75276: ['doc1640582']
# Relevante DocIDs für Query 75277: ['doc1706875']
# Relevante DocIDs für Query 75282: ['doc12400']
# Relevante DocIDs für Query 75283: ['doc12400']
# Relevante DocIDs für Query 75287: ['doc1682682', 'doc1706097', 'doc6732', 'doc10659']
# Relevante DocIDs für Query 75294: ['doc10376']
# Relevante DocIDs für Query 75296: ['doc25274']
# Relevante DocIDs für Query 75298: ['doc27472']
# Relevante DocIDs für Query 75299: ['doc21284']
# Relevante DocIDs für Query 75303: ['doc2914546', 'doc10877', 'doc7783']
# Relevante DocIDs für Query 75305: ['doc1691105', 'doc15288', 'doc2957']
# Relevante DocIDs für Query 75306: ['doc15875', 'doc14999', 'doc17444', 'doc17667']
# Relevante DocIDs für Query 75307: ['doc12392']
# Relevante DocIDs für Query 75310: ['doc9555']
# Relevante DocIDs für Query 75311: ['doc12400']
# Relevante DocIDs für Query 75312: ['doc27098']
# Relevante DocIDs für Query 75316: ['doc1673632']
# Relevante DocIDs für Query 75319: ['doc1594704', 'doc9923']
# Relevante DocIDs für Query 75323: ['doc1594704']
# Relevante DocIDs für Query 75333: ['doc713']
# Relevante DocIDs für Query 75354: ['doc1698003']
# Relevante DocIDs für Query 75357: ['doc7523']
# Relevante DocIDs für Query 75361: ['doc1706892']
# Relevante DocIDs für Query 75382: ['doc584', 'doc17223']
# Relevante DocIDs für Query 75383: ['doc1675387']
# Relevante DocIDs für Query 75384: ['doc27870', 'doc15740']

# %%
import pandas as pd
import re
from sqlalchemy import create_engine

# DB-Setup
DATABASE = "longeval-web"
USER = "dis18"
HOST = "db"
PORT = "5432"
PASSWORD = "dis182425"

# Verbindung zur PostgreSQL-Datenbank
engine = create_engine(f"postgresql+psycopg2://{USER}:{PASSWORD}@{HOST}:{PORT}/{DATABASE}")

# Tokenizer + Jaccard-Funktion
def tokenize(text):
    return set(re.findall(r'\w+', text.lower()))

def jaccard_similarity(text1, text2):
    tokens1 = tokenize(text1)
    tokens2 = tokenize(text2)
    return len(tokens1 & tokens2) / len(tokens1 | tokens2) if tokens1 | tokens2 else 0.0

# Vergleichsfunktion mit Fix für Duplikate
def compare_doc_texts(docids, threshold=0.9):
    if not docids:
        raise ValueError("Die Liste der docids ist leer.")
    
    query = f"""
        SELECT 
            "docid", 
            "sub_collection", 
            "text_fr"
        FROM "Document" 
        WHERE "docid" IN ({','.join([f"'{docid}'" for docid in docids])}) 
          AND "sub_collection" IN ('2023-02', '2023-04')
        ORDER BY "docid", "sub_collection"
    """
    
    df = pd.read_sql(query, con=engine)

    if df.empty:
        raise ValueError("Keine Daten für die angegebenen docids gefunden.")

    # Duplikate bereinigen
    df = df.drop_duplicates(subset=["docid", "sub_collection"], keep="first")

    # Pivot-Tabelle mit Textinhalten erstellen
    df_pivot = df.pivot(index="docid", columns="sub_collection", values="text_fr").dropna()

    # Berechne Jaccard-Score für jeden Doc
    df_pivot["jaccard_score"] = df_pivot.apply(
        lambda row: jaccard_similarity(row["2023-02"], row["2023-04"]), axis=1
    )

    # Filtere passende docids
    matching_docids = df_pivot[df_pivot["jaccard_score"] >= threshold].index.tolist()

    return df_pivot.reset_index(), matching_docids

# Beispielnutzung
filtered_query_doc_map = {}
all_docids = set(docid for docs in query_doc_map.values() for docid in docs)

_, matching_docids = compare_doc_texts(all_docids, threshold=0.9)
matching_docids_set = set(matching_docids)

# Filtere passende DocIDs und schneide 'doc' vorne weg
filtered_query_doc_map = {
    query_id: [docid[3:] for docid in docs if docid in matching_docids_set]
    for query_id, docs in query_doc_map.items()
}

# Ausgabe
for qid, docs in filtered_query_doc_map.items():
    print(f"Gefilterte DocIDs für Query {qid} (nur Zahl): {docs}")
# Out:
# Gefilterte DocIDs für Query 3 (nur Zahl): ['1646118']
# Gefilterte DocIDs für Query 8 (nur Zahl): ['19754']
# Gefilterte DocIDs für Query 12 (nur Zahl): ['20559', '22877']
# Gefilterte DocIDs für Query 18 (nur Zahl): ['19416', '18882']
# Gefilterte DocIDs für Query 19 (nur Zahl): ['8323']
# Gefilterte DocIDs für Query 20 (nur Zahl): ['1716', '4311']
# Gefilterte DocIDs für Query 23 (nur Zahl): []
# Gefilterte DocIDs für Query 24 (nur Zahl): ['8592']
# Gefilterte DocIDs für Query 26 (nur Zahl): ['3344995']
# Gefilterte DocIDs für Query 27 (nur Zahl): ['2588', '23258']
# Gefilterte DocIDs für Query 28 (nur Zahl): ['16256', '13703']
# Gefilterte DocIDs für Query 29 (nur Zahl): ['26747', '2869393']
# Gefilterte DocIDs für Query 30 (nur Zahl): ['2874670', '1644643', '955', '23020', '1706936']
# Gefilterte DocIDs für Query 32 (nur Zahl): ['2904587', '1688288']
# Gefilterte DocIDs für Query 33 (nur Zahl): ['1684120']
# Gefilterte DocIDs für Query 41 (nur Zahl): ['21116']
# Gefilterte DocIDs für Query 42 (nur Zahl): ['21520']
# Gefilterte DocIDs für Query 43 (nur Zahl): ['15389', '1698']
# Gefilterte DocIDs für Query 44 (nur Zahl): ['23717']
# Gefilterte DocIDs für Query 45 (nur Zahl): ['24032', '2908659']
# Gefilterte DocIDs für Query 46 (nur Zahl): ['25901']
# Gefilterte DocIDs für Query 49 (nur Zahl): ['1695753', '2868235']
# Gefilterte DocIDs für Query 50 (nur Zahl): []
# Gefilterte DocIDs für Query 51 (nur Zahl): ['236']
# Gefilterte DocIDs für Query 53 (nur Zahl): ['21337']
# Gefilterte DocIDs für Query 54 (nur Zahl): ['19445']
# Gefilterte DocIDs für Query 56 (nur Zahl): ['1367', '2651']
# Gefilterte DocIDs für Query 58 (nur Zahl): ['1614518', '1593606', '2874983']
# Gefilterte DocIDs für Query 60 (nur Zahl): ['1611735']
# Gefilterte DocIDs für Query 62 (nur Zahl): ['4850', '9584']
# Gefilterte DocIDs für Query 64 (nur Zahl): ['14843']
# Gefilterte DocIDs für Query 68 (nur Zahl): []
# Gefilterte DocIDs für Query 70 (nur Zahl): ['1589698']
# Gefilterte DocIDs für Query 71 (nur Zahl): []
# Gefilterte DocIDs für Query 76 (nur Zahl): []
# Gefilterte DocIDs für Query 81 (nur Zahl): ['1643098']
# Gefilterte DocIDs für Query 84 (nur Zahl): ['23562']
# Gefilterte DocIDs für Query 85 (nur Zahl): ['1925', '22776', '14125', '275']
# Gefilterte DocIDs für Query 89 (nur Zahl): ['21285']
# Gefilterte DocIDs für Query 91 (nur Zahl): ['9339']
# Gefilterte DocIDs für Query 93 (nur Zahl): ['19636']
# Gefilterte DocIDs für Query 95 (nur Zahl): ['11798', '1471']
# Gefilterte DocIDs für Query 98 (nur Zahl): []
# Gefilterte DocIDs für Query 99 (nur Zahl): ['24218']
# Gefilterte DocIDs für Query 100 (nur Zahl): ['1504']
# Gefilterte DocIDs für Query 103 (nur Zahl): ['11417']
# Gefilterte DocIDs für Query 107 (nur Zahl): ['15023', '3398320']
# Gefilterte DocIDs für Query 108 (nur Zahl): ['3005']
# Gefilterte DocIDs für Query 109 (nur Zahl): ['5600', '5527']
# Gefilterte DocIDs für Query 111 (nur Zahl): ['7037', '1321', '1367']
# Gefilterte DocIDs für Query 112 (nur Zahl): ['28191']
# Gefilterte DocIDs für Query 113 (nur Zahl): ['1590860', '3630']
# Gefilterte DocIDs für Query 114 (nur Zahl): ['1596769']
# Gefilterte DocIDs für Query 115 (nur Zahl): ['2914386']
# Gefilterte DocIDs für Query 116 (nur Zahl): ['1597381', '21345']
# Gefilterte DocIDs für Query 117 (nur Zahl): ['6593', '10011']
# Gefilterte DocIDs für Query 118 (nur Zahl): ['15773']
# Gefilterte DocIDs für Query 120 (nur Zahl): ['7113', '3395', '21843']
# Gefilterte DocIDs für Query 121 (nur Zahl): ['28989', '18712']
# Gefilterte DocIDs für Query 123 (nur Zahl): ['25080']
# Gefilterte DocIDs für Query 124 (nur Zahl): ['17586']
# Gefilterte DocIDs für Query 132 (nur Zahl): ['12433']
# Gefilterte DocIDs für Query 133 (nur Zahl): ['12433']
# Gefilterte DocIDs für Query 136 (nur Zahl): ['3359143']
# Gefilterte DocIDs für Query 139 (nur Zahl): ['2861584']
# Gefilterte DocIDs für Query 140 (nur Zahl): ['1706647', '1593851']
# Gefilterte DocIDs für Query 146 (nur Zahl): ['1597750']
# Gefilterte DocIDs für Query 148 (nur Zahl): ['1675809']
# Gefilterte DocIDs für Query 150 (nur Zahl): ['1646450']
# Gefilterte DocIDs für Query 152 (nur Zahl): ['1646038', '1201']
# Gefilterte DocIDs für Query 153 (nur Zahl): []
# Gefilterte DocIDs für Query 157 (nur Zahl): ['10189']
# Gefilterte DocIDs für Query 158 (nur Zahl): ['19830']
# Gefilterte DocIDs für Query 164 (nur Zahl): ['16256']
# Gefilterte DocIDs für Query 166 (nur Zahl): ['25513', '13601']
# Gefilterte DocIDs für Query 168 (nur Zahl): ['1597574', '1593593', '2907447', '1591067']
# Gefilterte DocIDs für Query 172 (nur Zahl): ['2360']
# Gefilterte DocIDs für Query 173 (nur Zahl): ['4739']
# Gefilterte DocIDs für Query 181 (nur Zahl): ['4739']
# Gefilterte DocIDs für Query 192 (nur Zahl): ['1611158']
# Gefilterte DocIDs für Query 196 (nur Zahl): ['17553', '1700158']
# Gefilterte DocIDs für Query 199 (nur Zahl): ['1611158']
# Gefilterte DocIDs für Query 202 (nur Zahl): ['1682235']
# Gefilterte DocIDs für Query 219 (nur Zahl): ['13027']
# Gefilterte DocIDs für Query 220 (nur Zahl): ['2867581', '1593363', '1612718']
# Gefilterte DocIDs für Query 221 (nur Zahl): ['1595886', '8043', '10167']
# Gefilterte DocIDs für Query 222 (nur Zahl): []
# Gefilterte DocIDs für Query 224 (nur Zahl): ['1676341']
# Gefilterte DocIDs für Query 227 (nur Zahl): ['9419']
# Gefilterte DocIDs für Query 230 (nur Zahl): ['1693655']
# Gefilterte DocIDs für Query 236 (nur Zahl): ['10018']
# Gefilterte DocIDs für Query 237 (nur Zahl): ['21279']
# Gefilterte DocIDs für Query 238 (nur Zahl): []
# Gefilterte DocIDs für Query 243 (nur Zahl): ['1672632', '1702754']
# Gefilterte DocIDs für Query 249 (nur Zahl): []
# Gefilterte DocIDs für Query 250 (nur Zahl): []
# Gefilterte DocIDs für Query 252 (nur Zahl): ['16872', '24677', '9475', '9880']
# Gefilterte DocIDs für Query 253 (nur Zahl): []
# Gefilterte DocIDs für Query 259 (nur Zahl): ['1677863']
# Gefilterte DocIDs für Query 264 (nur Zahl): ['3422526']
# Gefilterte DocIDs für Query 266 (nur Zahl): ['29188']
# Gefilterte DocIDs für Query 267 (nur Zahl): ['18221', '19724']
# Gefilterte DocIDs für Query 271 (nur Zahl): ['16127', '1644210', '2606', '3346130']
# Gefilterte DocIDs für Query 273 (nur Zahl): ['25769', '2867564', '11236', '1688203']
# Gefilterte DocIDs für Query 274 (nur Zahl): ['17195', '25769', '557', '1689425', '1688203']
# Gefilterte DocIDs für Query 285 (nur Zahl): ['25441']
# Gefilterte DocIDs für Query 286 (nur Zahl): ['142']
# Gefilterte DocIDs für Query 294 (nur Zahl): ['2897332']
# Gefilterte DocIDs für Query 295 (nur Zahl): ['21307']
# Gefilterte DocIDs für Query 299 (nur Zahl): ['1687486']
# Gefilterte DocIDs für Query 303 (nur Zahl): ['2875562', '2859567']
# Gefilterte DocIDs für Query 305 (nur Zahl): ['15875']
# Gefilterte DocIDs für Query 306 (nur Zahl): ['15875', '215', '14945']
# Gefilterte DocIDs für Query 308 (nur Zahl): ['2896816']
# Gefilterte DocIDs für Query 310 (nur Zahl): ['1687297']
# Gefilterte DocIDs für Query 313 (nur Zahl): ['1697167', '1697180']
# Gefilterte DocIDs für Query 317 (nur Zahl): ['1596412', '1590654']
# Gefilterte DocIDs für Query 323 (nur Zahl): ['1591143']
# Gefilterte DocIDs für Query 325 (nur Zahl): ['7496']
# Gefilterte DocIDs für Query 326 (nur Zahl): ['22646']
# Gefilterte DocIDs für Query 328 (nur Zahl): ['15861', '7066', '1999']
# Gefilterte DocIDs für Query 329 (nur Zahl): ['1682173']
# Gefilterte DocIDs für Query 332 (nur Zahl): ['1692833', '1681443']
# Gefilterte DocIDs für Query 333 (nur Zahl): ['7066']
# Gefilterte DocIDs für Query 334 (nur Zahl): ['2860903']
# Gefilterte DocIDs für Query 335 (nur Zahl): ['1695942']
# Gefilterte DocIDs für Query 337 (nur Zahl): ['21240', '1796']
# Gefilterte DocIDs für Query 338 (nur Zahl): ['2877599']
# Gefilterte DocIDs für Query 341 (nur Zahl): ['21284']
# Gefilterte DocIDs für Query 343 (nur Zahl): ['21284']
# Gefilterte DocIDs für Query 346 (nur Zahl): ['1672484']
# Gefilterte DocIDs für Query 347 (nur Zahl): ['1695383', '1691966']
# Gefilterte DocIDs für Query 348 (nur Zahl): ['1610992', '1616581']
# Gefilterte DocIDs für Query 350 (nur Zahl): ['1676374']
# Gefilterte DocIDs für Query 353 (nur Zahl): ['1613691']
# Gefilterte DocIDs für Query 355 (nur Zahl): ['14114']
# Gefilterte DocIDs für Query 357 (nur Zahl): []
# Gefilterte DocIDs für Query 358 (nur Zahl): ['1640434', '22442', '2911536', '4259']
# Gefilterte DocIDs für Query 362 (nur Zahl): ['6381']
# Gefilterte DocIDs für Query 363 (nur Zahl): ['24675']
# Gefilterte DocIDs für Query 366 (nur Zahl): ['1970']
# Gefilterte DocIDs für Query 370 (nur Zahl): ['14497']
# Gefilterte DocIDs für Query 371 (nur Zahl): ['6032', '111080']
# Gefilterte DocIDs für Query 374 (nur Zahl): ['1687046', '1701418']
# Gefilterte DocIDs für Query 376 (nur Zahl): ['3357561']
# Gefilterte DocIDs für Query 377 (nur Zahl): []
# Gefilterte DocIDs für Query 381 (nur Zahl): ['28161']
# Gefilterte DocIDs für Query 382 (nur Zahl): ['1680583']
# Gefilterte DocIDs für Query 384 (nur Zahl): ['2903298', '1671961']
# Gefilterte DocIDs für Query 392 (nur Zahl): []
# Gefilterte DocIDs für Query 393 (nur Zahl): ['1695319', '1596709', '1615724']
# Gefilterte DocIDs für Query 395 (nur Zahl): ['1688963', '5003', '1687454', '15663']
# Gefilterte DocIDs für Query 396 (nur Zahl): ['1705249', '1703177']
# Gefilterte DocIDs für Query 399 (nur Zahl): ['1592135']
# Gefilterte DocIDs für Query 402 (nur Zahl): ['6100']
# Gefilterte DocIDs für Query 404 (nur Zahl): ['2911822']
# Gefilterte DocIDs für Query 407 (nur Zahl): ['2864912']
# Gefilterte DocIDs für Query 410 (nur Zahl): ['26758', '22507']
# Gefilterte DocIDs für Query 411 (nur Zahl): ['17381']
# Gefilterte DocIDs für Query 416 (nur Zahl): []
# Gefilterte DocIDs für Query 418 (nur Zahl): []
# Gefilterte DocIDs für Query 420 (nur Zahl): ['4903']
# Gefilterte DocIDs für Query 423 (nur Zahl): ['1697655']
# Gefilterte DocIDs für Query 432 (nur Zahl): ['1591250', '1689352', '2903774']
# Gefilterte DocIDs für Query 433 (nur Zahl): []
# Gefilterte DocIDs für Query 437 (nur Zahl): ['1613551']
# Gefilterte DocIDs für Query 438 (nur Zahl): ['17423']
# Gefilterte DocIDs für Query 440 (nur Zahl): ['8644']
# Gefilterte DocIDs für Query 442 (nur Zahl): ['2872021']
# Gefilterte DocIDs für Query 450 (nur Zahl): ['1674123']
# Gefilterte DocIDs für Query 451 (nur Zahl): ['1641205']
# Gefilterte DocIDs für Query 452 (nur Zahl): ['1686463', '1596410']
# Gefilterte DocIDs für Query 454 (nur Zahl): ['1692715']
# Gefilterte DocIDs für Query 456 (nur Zahl): ['3432481']
# Gefilterte DocIDs für Query 457 (nur Zahl): ['1705947', '1690995']
# Gefilterte DocIDs für Query 459 (nur Zahl): ['2523']
# Gefilterte DocIDs für Query 461 (nur Zahl): []
# Gefilterte DocIDs für Query 463 (nur Zahl): ['29079', '10570']
# Gefilterte DocIDs für Query 466 (nur Zahl): ['2907717']
# Gefilterte DocIDs für Query 467 (nur Zahl): ['1683759']
# Gefilterte DocIDs für Query 469 (nur Zahl): []
# Gefilterte DocIDs für Query 472 (nur Zahl): ['11702', '310']
# Gefilterte DocIDs für Query 479 (nur Zahl): ['29079']
# Gefilterte DocIDs für Query 483 (nur Zahl): ['1677668']
# Gefilterte DocIDs für Query 485 (nur Zahl): ['1701097']
# Gefilterte DocIDs für Query 490 (nur Zahl): ['1640859']
# Gefilterte DocIDs für Query 491 (nur Zahl): []
# Gefilterte DocIDs für Query 494 (nur Zahl): ['1707947']
# Gefilterte DocIDs für Query 500 (nur Zahl): []
# Gefilterte DocIDs für Query 504 (nur Zahl): ['13317']
# Gefilterte DocIDs für Query 508 (nur Zahl): ['1673237']
# Gefilterte DocIDs für Query 509 (nur Zahl): ['1612443']
# Gefilterte DocIDs für Query 510 (nur Zahl): ['1673548', '1699037']
# Gefilterte DocIDs für Query 512 (nur Zahl): []
# Gefilterte DocIDs für Query 519 (nur Zahl): ['1675581']
# Gefilterte DocIDs für Query 522 (nur Zahl): ['1958']
# Gefilterte DocIDs für Query 531 (nur Zahl): ['110']
# Gefilterte DocIDs für Query 532 (nur Zahl): ['7930', '1698273', '10659', '10605']
# Gefilterte DocIDs für Query 533 (nur Zahl): ['10659', '6732', '1706647', '1698273', '1706097', '1693925']
# Gefilterte DocIDs für Query 534 (nur Zahl): ['1701533', '1706647', '1704337']
# Gefilterte DocIDs für Query 535 (nur Zahl): ['1675229']
# Gefilterte DocIDs für Query 537 (nur Zahl): ['1674119', '1673230']
# Gefilterte DocIDs für Query 540 (nur Zahl): ['18379', '1595541', '10303', '1697899']
# Gefilterte DocIDs für Query 543 (nur Zahl): ['9551', '27993']
# Gefilterte DocIDs für Query 544 (nur Zahl): ['1694811']
# Gefilterte DocIDs für Query 547 (nur Zahl): ['27227']
# Gefilterte DocIDs für Query 548 (nur Zahl): ['3958', '1561', '27227', '28975']
# Gefilterte DocIDs für Query 557 (nur Zahl): []
# Gefilterte DocIDs für Query 565 (nur Zahl): ['11334', '25941']
# Gefilterte DocIDs für Query 571 (nur Zahl): ['1611468']
# Gefilterte DocIDs für Query 572 (nur Zahl): []
# Gefilterte DocIDs für Query 578 (nur Zahl): ['13984']
# Gefilterte DocIDs für Query 585 (nur Zahl): ['1694611']
# Gefilterte DocIDs für Query 587 (nur Zahl): ['1614131']
# Gefilterte DocIDs für Query 588 (nur Zahl): ['25325']
# Gefilterte DocIDs für Query 595 (nur Zahl): ['17774']
# Gefilterte DocIDs für Query 603 (nur Zahl): ['11599', '1679402']
# Gefilterte DocIDs für Query 604 (nur Zahl): []
# Gefilterte DocIDs für Query 605 (nur Zahl): ['2863205']
# Gefilterte DocIDs für Query 607 (nur Zahl): ['3582']
# Gefilterte DocIDs für Query 608 (nur Zahl): []
# Gefilterte DocIDs für Query 609 (nur Zahl): ['3958', '2861389', '3679', '18922', '24236']
# Gefilterte DocIDs für Query 611 (nur Zahl): ['23310', '1164', '5407']
# Gefilterte DocIDs für Query 613 (nur Zahl): ['2875317']
# Gefilterte DocIDs für Query 614 (nur Zahl): ['2860776']
# Gefilterte DocIDs für Query 615 (nur Zahl): ['29032']
# Gefilterte DocIDs für Query 616 (nur Zahl): ['13058']
# Gefilterte DocIDs für Query 617 (nur Zahl): ['23838', '13071', '21571']
# Gefilterte DocIDs für Query 618 (nur Zahl): ['8591']
# Gefilterte DocIDs für Query 619 (nur Zahl): ['18048']
# Gefilterte DocIDs für Query 620 (nur Zahl): ['1591694']
# Gefilterte DocIDs für Query 621 (nur Zahl): ['10994', '1681986']
# Gefilterte DocIDs für Query 622 (nur Zahl): ['22737']
# Gefilterte DocIDs für Query 623 (nur Zahl): ['5369', '13123', '2909948']
# Gefilterte DocIDs für Query 624 (nur Zahl): ['1671498']
# Gefilterte DocIDs für Query 625 (nur Zahl): ['15687']
# Gefilterte DocIDs für Query 626 (nur Zahl): ['15687', '21163', '2865341']
# Gefilterte DocIDs für Query 627 (nur Zahl): ['15687']
# Gefilterte DocIDs für Query 629 (nur Zahl): ['13153', '7385']
# Gefilterte DocIDs für Query 636 (nur Zahl): ['1694858', '1700538']
# Gefilterte DocIDs für Query 643 (nur Zahl): ['14758']
# Gefilterte DocIDs für Query 648 (nur Zahl): ['5806']
# Gefilterte DocIDs für Query 649 (nur Zahl): ['1595782', '1591706', '1593255']
# Gefilterte DocIDs für Query 651 (nur Zahl): []
# Gefilterte DocIDs für Query 653 (nur Zahl): ['1681646']
# Gefilterte DocIDs für Query 657 (nur Zahl): ['19724']
# Gefilterte DocIDs für Query 658 (nur Zahl): ['19724']
# Gefilterte DocIDs für Query 659 (nur Zahl): ['3864']
# Gefilterte DocIDs für Query 664 (nur Zahl): ['15667']
# Gefilterte DocIDs für Query 666 (nur Zahl): ['3363852']
# Gefilterte DocIDs für Query 671 (nur Zahl): ['3348173']
# Gefilterte DocIDs für Query 672 (nur Zahl): []
# Gefilterte DocIDs für Query 673 (nur Zahl): ['8954', '7429', '2010']
# Gefilterte DocIDs für Query 675 (nur Zahl): ['1641788']
# Gefilterte DocIDs für Query 679 (nur Zahl): ['1696929']
# Gefilterte DocIDs für Query 683 (nur Zahl): ['1689892']
# Gefilterte DocIDs für Query 684 (nur Zahl): ['1704260']
# Gefilterte DocIDs für Query 685 (nur Zahl): ['28256']
# Gefilterte DocIDs für Query 688 (nur Zahl): ['22426']
# Gefilterte DocIDs für Query 692 (nur Zahl): ['1596355', '2910533']
# Gefilterte DocIDs für Query 693 (nur Zahl): ['1591687']
# Gefilterte DocIDs für Query 694 (nur Zahl): ['5592']
# Gefilterte DocIDs für Query 696 (nur Zahl): ['1696693', '1682109']
# Gefilterte DocIDs für Query 699 (nur Zahl): ['6251', '11205', '7947']
# Gefilterte DocIDs für Query 701 (nur Zahl): []
# Gefilterte DocIDs für Query 706 (nur Zahl): ['21926']
# Gefilterte DocIDs für Query 708 (nur Zahl): ['1597668']
# Gefilterte DocIDs für Query 713 (nur Zahl): []
# Gefilterte DocIDs für Query 719 (nur Zahl): ['2136', '28861']
# Gefilterte DocIDs für Query 720 (nur Zahl): ['1707265']
# Gefilterte DocIDs für Query 721 (nur Zahl): []
# Gefilterte DocIDs für Query 722 (nur Zahl): ['1703224']
# Gefilterte DocIDs für Query 723 (nur Zahl): ['1706166']
# Gefilterte DocIDs für Query 726 (nur Zahl): []
# Gefilterte DocIDs für Query 728 (nur Zahl): ['16029']
# Gefilterte DocIDs für Query 729 (nur Zahl): ['27126', '16029', '785']
# Gefilterte DocIDs für Query 733 (nur Zahl): ['1591878', '1593097']
# Gefilterte DocIDs für Query 736 (nur Zahl): ['1679932']
# Gefilterte DocIDs für Query 740 (nur Zahl): ['25735', '19053']
# Gefilterte DocIDs für Query 742 (nur Zahl): ['1592756']
# Gefilterte DocIDs für Query 745 (nur Zahl): ['1597721']
# Gefilterte DocIDs für Query 747 (nur Zahl): ['25323', '9358', '15315']
# Gefilterte DocIDs für Query 748 (nur Zahl): ['16599', '5618']
# Gefilterte DocIDs für Query 750 (nur Zahl): ['21284']
# Gefilterte DocIDs für Query 751 (nur Zahl): ['1685816']
# Gefilterte DocIDs für Query 752 (nur Zahl): ['4903']
# Gefilterte DocIDs für Query 753 (nur Zahl): ['4903']
# Gefilterte DocIDs für Query 755 (nur Zahl): ['4903']
# Gefilterte DocIDs für Query 756 (nur Zahl): ['1090']
# Gefilterte DocIDs für Query 760 (nur Zahl): ['3378285']
# Gefilterte DocIDs für Query 763 (nur Zahl): ['11105', '3359852']
# Gefilterte DocIDs für Query 765 (nur Zahl): ['3359852']
# Gefilterte DocIDs für Query 770 (nur Zahl): ['1595967', '25738']
# Gefilterte DocIDs für Query 774 (nur Zahl): ['1679489', '9038', '1707719']
# Gefilterte DocIDs für Query 783 (nur Zahl): ['1705726', '1594268']
# Gefilterte DocIDs für Query 784 (nur Zahl): ['1596946', '1594268', '28484']
# Gefilterte DocIDs für Query 785 (nur Zahl): ['13287', '2898010', '1598197']
# Gefilterte DocIDs für Query 789 (nur Zahl): ['28861']
# Gefilterte DocIDs für Query 790 (nur Zahl): ['2404']
# Gefilterte DocIDs für Query 795 (nur Zahl): ['6689']
# Gefilterte DocIDs für Query 801 (nur Zahl): ['1674056']
# Gefilterte DocIDs für Query 802 (nur Zahl): ['1596737']
# Gefilterte DocIDs für Query 803 (nur Zahl): ['7688']
# Gefilterte DocIDs für Query 804 (nur Zahl): ['22774', '24519', '1653']
# Gefilterte DocIDs für Query 807 (nur Zahl): ['13030', '7291', '2735']
# Gefilterte DocIDs für Query 810 (nur Zahl): ['1687269']
# Gefilterte DocIDs für Query 813 (nur Zahl): ['9626']
# Gefilterte DocIDs für Query 820 (nur Zahl): []
# Gefilterte DocIDs für Query 822 (nur Zahl): []
# Gefilterte DocIDs für Query 825 (nur Zahl): ['22693']
# Gefilterte DocIDs für Query 827 (nur Zahl): ['13693']
# Gefilterte DocIDs für Query 830 (nur Zahl): ['29238', '2921599', '28447']
# Gefilterte DocIDs für Query 831 (nur Zahl): ['6549', '22604', '22668', '16551']
# Gefilterte DocIDs für Query 832 (nur Zahl): ['1644018']
# Gefilterte DocIDs für Query 837 (nur Zahl): ['1693351']
# Gefilterte DocIDs für Query 842 (nur Zahl): ['2917354', '2918664']
# Gefilterte DocIDs für Query 843 (nur Zahl): ['1592712']
# Gefilterte DocIDs für Query 850 (nur Zahl): ['1671641']
# Gefilterte DocIDs für Query 851 (nur Zahl): []
# Gefilterte DocIDs für Query 852 (nur Zahl): ['1687131']
# Gefilterte DocIDs für Query 855 (nur Zahl): []
# Gefilterte DocIDs für Query 856 (nur Zahl): []
# Gefilterte DocIDs für Query 857 (nur Zahl): []
# Gefilterte DocIDs für Query 858 (nur Zahl): ['1676477']
# Gefilterte DocIDs für Query 859 (nur Zahl): ['1698541']
# Gefilterte DocIDs für Query 860 (nur Zahl): ['1685742']
# Gefilterte DocIDs für Query 861 (nur Zahl): ['1673463']
# Gefilterte DocIDs für Query 864 (nur Zahl): []
# Gefilterte DocIDs für Query 867 (nur Zahl): ['2916280']
# Gefilterte DocIDs für Query 868 (nur Zahl): []
# Gefilterte DocIDs für Query 869 (nur Zahl): ['1701592']
# Gefilterte DocIDs für Query 873 (nur Zahl): ['1691135']
# Gefilterte DocIDs für Query 874 (nur Zahl): ['28195']
# Gefilterte DocIDs für Query 876 (nur Zahl): ['26305']
# Gefilterte DocIDs für Query 877 (nur Zahl): ['10385', '19505', '8851']
# Gefilterte DocIDs für Query 886 (nur Zahl): ['1684142', '1058', '9555']
# Gefilterte DocIDs für Query 887 (nur Zahl): []
# Gefilterte DocIDs für Query 889 (nur Zahl): ['1683335']
# Gefilterte DocIDs für Query 890 (nur Zahl): ['25521']
# Gefilterte DocIDs für Query 893 (nur Zahl): ['15672']
# Gefilterte DocIDs für Query 896 (nur Zahl): ['2910645']
# Gefilterte DocIDs für Query 897 (nur Zahl): ['25521']
# Gefilterte DocIDs für Query 900 (nur Zahl): ['1697218']
# Gefilterte DocIDs für Query 905 (nur Zahl): ['28529', '9990']
# Gefilterte DocIDs für Query 906 (nur Zahl): ['9990', '28529']
# Gefilterte DocIDs für Query 907 (nur Zahl): ['18639']
# Gefilterte DocIDs für Query 908 (nur Zahl): ['15672']
# Gefilterte DocIDs für Query 910 (nur Zahl): ['1683335', '1683750']
# Gefilterte DocIDs für Query 913 (nur Zahl): ['1685217']
# Gefilterte DocIDs für Query 914 (nur Zahl): ['1590283']
# Gefilterte DocIDs für Query 916 (nur Zahl): []
# Gefilterte DocIDs für Query 919 (nur Zahl): ['12017']
# Gefilterte DocIDs für Query 923 (nur Zahl): ['23058']
# Gefilterte DocIDs für Query 930 (nur Zahl): ['1616572']
# Gefilterte DocIDs für Query 934 (nur Zahl): ['11400']
# Gefilterte DocIDs für Query 935 (nur Zahl): ['1593282', '1591617', '1595865', '1591720']
# Gefilterte DocIDs für Query 936 (nur Zahl): ['21047']
# Gefilterte DocIDs für Query 938 (nur Zahl): ['6089']
# Gefilterte DocIDs für Query 940 (nur Zahl): ['13860', '1670594', '24741', '1598162']
# Gefilterte DocIDs für Query 941 (nur Zahl): ['1677632', '1702374']
# Gefilterte DocIDs für Query 942 (nur Zahl): []
# Gefilterte DocIDs für Query 950 (nur Zahl): ['1695047', '3408015']
# Gefilterte DocIDs für Query 952 (nur Zahl): ['14999', '15875', '17667', '17444']
# Gefilterte DocIDs für Query 954 (nur Zahl): ['2286', '15875', '5325', '17444']
# Gefilterte DocIDs für Query 956 (nur Zahl): []
# Gefilterte DocIDs für Query 957 (nur Zahl): ['8612']
# Gefilterte DocIDs für Query 959 (nur Zahl): ['12400']
# Gefilterte DocIDs für Query 961 (nur Zahl): ['12400']
# Gefilterte DocIDs für Query 963 (nur Zahl): ['12400']
# Gefilterte DocIDs für Query 964 (nur Zahl): ['1646070', '8617', '24741', '12400', '2912698']
# Gefilterte DocIDs für Query 965 (nur Zahl): ['12400']
# Gefilterte DocIDs für Query 967 (nur Zahl): ['18733']
# Gefilterte DocIDs für Query 969 (nur Zahl): ['10078']
# Gefilterte DocIDs für Query 972 (nur Zahl): ['12400']
# Gefilterte DocIDs für Query 973 (nur Zahl): ['14999', '15875']
# Gefilterte DocIDs für Query 976 (nur Zahl): ['12400']
# Gefilterte DocIDs für Query 977 (nur Zahl): ['29213']
# Gefilterte DocIDs für Query 981 (nur Zahl): ['20631']
# Gefilterte DocIDs für Query 982 (nur Zahl): ['20631']
# Gefilterte DocIDs für Query 984 (nur Zahl): ['10613', '12118', '13102']
# Gefilterte DocIDs für Query 986 (nur Zahl): ['24460']
# Gefilterte DocIDs für Query 990 (nur Zahl): ['18673']
# Gefilterte DocIDs für Query 992 (nur Zahl): ['13560']
# Gefilterte DocIDs für Query 996 (nur Zahl): ['1406', '6968']
# Gefilterte DocIDs für Query 1000 (nur Zahl): ['7496']
# Gefilterte DocIDs für Query 1006 (nur Zahl): ['2919184', '11595']
# Gefilterte DocIDs für Query 1007 (nur Zahl): ['1692572']
# Gefilterte DocIDs für Query 1009 (nur Zahl): ['12400']
# Gefilterte DocIDs für Query 1016 (nur Zahl): ['2864']
# Gefilterte DocIDs für Query 1017 (nur Zahl): ['25421', '8511']
# Gefilterte DocIDs für Query 1018 (nur Zahl): ['2908973']
# Gefilterte DocIDs für Query 1019 (nur Zahl): ['4850']
# Gefilterte DocIDs für Query 1021 (nur Zahl): ['8519', '3258']
# Gefilterte DocIDs für Query 1022 (nur Zahl): ['1644880']
# Gefilterte DocIDs für Query 1023 (nur Zahl): ['1405']
# Gefilterte DocIDs für Query 1026 (nur Zahl): ['11156', '2760']
# Gefilterte DocIDs für Query 1027 (nur Zahl): ['1661']
# Gefilterte DocIDs für Query 1028 (nur Zahl): ['3258', '8519']
# Gefilterte DocIDs für Query 1029 (nur Zahl): ['7268']
# Gefilterte DocIDs für Query 1033 (nur Zahl): ['955', '1644643']
# Gefilterte DocIDs für Query 1039 (nur Zahl): ['21778']
# Gefilterte DocIDs für Query 1042 (nur Zahl): ['26639']
# Gefilterte DocIDs für Query 1045 (nur Zahl): ['21153', '19276']
# Gefilterte DocIDs für Query 1047 (nur Zahl): ['20164']
# Gefilterte DocIDs für Query 1050 (nur Zahl): ['3928', '1591823']
# Gefilterte DocIDs für Query 1052 (nur Zahl): []
# Gefilterte DocIDs für Query 1053 (nur Zahl): ['9817']
# Gefilterte DocIDs für Query 1054 (nur Zahl): ['2912507', '25396']
# Gefilterte DocIDs für Query 1055 (nur Zahl): ['1696']
# Gefilterte DocIDs für Query 1059 (nur Zahl): ['17176']
# Gefilterte DocIDs für Query 1060 (nur Zahl): ['19489']
# Gefilterte DocIDs für Query 1061 (nur Zahl): ['1643653']
# Gefilterte DocIDs für Query 1065 (nur Zahl): ['29003']
# Gefilterte DocIDs für Query 1067 (nur Zahl): ['2878914']
# Gefilterte DocIDs für Query 1068 (nur Zahl): ['13708', '1641360', '28660']
# Gefilterte DocIDs für Query 1070 (nur Zahl): ['24975']
# Gefilterte DocIDs für Query 1071 (nur Zahl): ['24975']
# Gefilterte DocIDs für Query 1072 (nur Zahl): ['4172']
# Gefilterte DocIDs für Query 1075 (nur Zahl): ['2859']
# Gefilterte DocIDs für Query 1079 (nur Zahl): ['2381']
# Gefilterte DocIDs für Query 1080 (nur Zahl): ['1841']
# Gefilterte DocIDs für Query 1081 (nur Zahl): ['23355', '23774']
# Gefilterte DocIDs für Query 1084 (nur Zahl): ['9551']
# Gefilterte DocIDs für Query 1085 (nur Zahl): ['29000', '2874657', '3118', '28208']
# Gefilterte DocIDs für Query 1092 (nur Zahl): ['1644880']
# Gefilterte DocIDs für Query 1098 (nur Zahl): ['14256', '17932']
# Gefilterte DocIDs für Query 1099 (nur Zahl): ['22502', '19137']
# Gefilterte DocIDs für Query 1102 (nur Zahl): ['10482']
# Gefilterte DocIDs für Query 1103 (nur Zahl): ['10482']
# Gefilterte DocIDs für Query 1106 (nur Zahl): ['1699730']
# Gefilterte DocIDs für Query 1109 (nur Zahl): ['6678', '20089']
# Gefilterte DocIDs für Query 1110 (nur Zahl): ['20089']
# Gefilterte DocIDs für Query 1115 (nur Zahl): ['3415511']
# Gefilterte DocIDs für Query 1120 (nur Zahl): ['19337']
# Gefilterte DocIDs für Query 1123 (nur Zahl): ['23835', '13626']
# Gefilterte DocIDs für Query 1128 (nur Zahl): ['7819']
# Gefilterte DocIDs für Query 1139 (nur Zahl): ['3108']
# Gefilterte DocIDs für Query 1140 (nur Zahl): ['19227']
# Gefilterte DocIDs für Query 1141 (nur Zahl): ['16977']
# Gefilterte DocIDs für Query 1145 (nur Zahl): ['23785']
# Gefilterte DocIDs für Query 1147 (nur Zahl): ['5832']
# Gefilterte DocIDs für Query 1148 (nur Zahl): ['1778']
# Gefilterte DocIDs für Query 1149 (nur Zahl): ['1778', '1593402']
# Gefilterte DocIDs für Query 1151 (nur Zahl): []
# Gefilterte DocIDs für Query 1155 (nur Zahl): ['1683806']
# Gefilterte DocIDs für Query 1156 (nur Zahl): ['1688034', '1597275']
# Gefilterte DocIDs für Query 1161 (nur Zahl): ['1684130', '1699707']
# Gefilterte DocIDs für Query 1164 (nur Zahl): []
# Gefilterte DocIDs für Query 1165 (nur Zahl): ['1610470']
# Gefilterte DocIDs für Query 1167 (nur Zahl): ['1706923']
# Gefilterte DocIDs für Query 1173 (nur Zahl): ['1402', '27167', '1504']
# Gefilterte DocIDs für Query 1174 (nur Zahl): ['1641656']
# Gefilterte DocIDs für Query 1177 (nur Zahl): ['3580', '20039']
# Gefilterte DocIDs für Query 1178 (nur Zahl): ['2914067']
# Gefilterte DocIDs für Query 1179 (nur Zahl): ['11042']
# Gefilterte DocIDs für Query 1182 (nur Zahl): ['1643282']
# Gefilterte DocIDs für Query 1186 (nur Zahl): ['8511']
# Gefilterte DocIDs für Query 1191 (nur Zahl): []
# Gefilterte DocIDs für Query 1195 (nur Zahl): ['1593363', '1682448']
# Gefilterte DocIDs für Query 1200 (nur Zahl): ['9974']
# Gefilterte DocIDs für Query 1201 (nur Zahl): ['1976', '17121', '7536']
# Gefilterte DocIDs für Query 1202 (nur Zahl): ['18631']
# Gefilterte DocIDs für Query 1204 (nur Zahl): ['1613161']
# Gefilterte DocIDs für Query 1205 (nur Zahl): ['1613161']
# Gefilterte DocIDs für Query 1208 (nur Zahl): []
# Gefilterte DocIDs für Query 1209 (nur Zahl): ['10416']
# Gefilterte DocIDs für Query 1211 (nur Zahl): ['20541', '1673045']
# Gefilterte DocIDs für Query 1213 (nur Zahl): ['1680057', '3357843', '12838']
# Gefilterte DocIDs für Query 1215 (nur Zahl): ['18364', '1673684']
# Gefilterte DocIDs für Query 1216 (nur Zahl): ['1683949', '1687171', '1695891', '1705700', '1699279', '1697336', '1705782', '1696003', '8509', '1706975']
# Gefilterte DocIDs für Query 1217 (nur Zahl): ['27653', '8509', '27972']
# Gefilterte DocIDs für Query 1219 (nur Zahl): ['1706105']
# Gefilterte DocIDs für Query 1221 (nur Zahl): ['1679283', '1704432']
# Gefilterte DocIDs für Query 1227 (nur Zahl): ['1684145', '2914931']
# Gefilterte DocIDs für Query 1228 (nur Zahl): ['1694720', '1686637', '2898807']
# Gefilterte DocIDs für Query 1229 (nur Zahl): ['1699166']
# Gefilterte DocIDs für Query 1230 (nur Zahl): ['2903416', '1595720', '1597401', '1592899']
# Gefilterte DocIDs für Query 1232 (nur Zahl): ['1688670']
# Gefilterte DocIDs für Query 1234 (nur Zahl): ['1687211', '1679909']
# Gefilterte DocIDs für Query 1238 (nur Zahl): ['24210']
# Gefilterte DocIDs für Query 1239 (nur Zahl): ['1703434', '1707380', '16232']
# Gefilterte DocIDs für Query 1240 (nur Zahl): ['27653']
# Gefilterte DocIDs für Query 1241 (nur Zahl): []
# Gefilterte DocIDs für Query 1243 (nur Zahl): ['7193']
# Gefilterte DocIDs für Query 1245 (nur Zahl): ['20896', '1701166']
# Gefilterte DocIDs für Query 1247 (nur Zahl): ['713']
# Gefilterte DocIDs für Query 1252 (nur Zahl): ['1053']
# Gefilterte DocIDs für Query 1257 (nur Zahl): ['2900839', '2906159']
# Gefilterte DocIDs für Query 1259 (nur Zahl): ['2863495', '1595469']
# Gefilterte DocIDs für Query 1263 (nur Zahl): ['1707210']
# Gefilterte DocIDs für Query 1273 (nur Zahl): ['14761']
# Gefilterte DocIDs für Query 1274 (nur Zahl): ['1860']
# Gefilterte DocIDs für Query 1279 (nur Zahl): ['1707231']
# Gefilterte DocIDs für Query 1280 (nur Zahl): ['42']
# Gefilterte DocIDs für Query 1283 (nur Zahl): ['26170']
# Gefilterte DocIDs für Query 1287 (nur Zahl): []
# Gefilterte DocIDs für Query 1289 (nur Zahl): ['19995']
# Gefilterte DocIDs für Query 1290 (nur Zahl): ['8284', '24811']
# Gefilterte DocIDs für Query 1292 (nur Zahl): ['29040']
# Gefilterte DocIDs für Query 1295 (nur Zahl): ['6359', '14907']
# Gefilterte DocIDs für Query 1296 (nur Zahl): ['18143']
# Gefilterte DocIDs für Query 1297 (nur Zahl): ['10177']
# Gefilterte DocIDs für Query 1300 (nur Zahl): ['5306']
# Gefilterte DocIDs für Query 1301 (nur Zahl): ['20563']
# Gefilterte DocIDs für Query 1302 (nur Zahl): ['20563']
# Gefilterte DocIDs für Query 1304 (nur Zahl): ['27057']
# Gefilterte DocIDs für Query 1306 (nur Zahl): ['1646130']
# Gefilterte DocIDs für Query 1307 (nur Zahl): ['2654']
# Gefilterte DocIDs für Query 1312 (nur Zahl): ['1676906']
# Gefilterte DocIDs für Query 1314 (nur Zahl): ['1670906', '1689374', '1684716', '1680991', '1693747', '1691703', '1675708']
# Gefilterte DocIDs für Query 1315 (nur Zahl): ['4364', '1694225', '20896']
# Gefilterte DocIDs für Query 1318 (nur Zahl): ['1671538', '20541', '1682322', '1678982', '1679900', '1676293', '2870264']
# Gefilterte DocIDs für Query 1319 (nur Zahl): ['1703617', '1697201', '1700177', '1676924', '1684324', '1685382']
# Gefilterte DocIDs für Query 1321 (nur Zahl): ['9187', '5132']
# Gefilterte DocIDs für Query 1326 (nur Zahl): ['1688283']
# Gefilterte DocIDs für Query 1327 (nur Zahl): []
# Gefilterte DocIDs für Query 1328 (nur Zahl): []
# Gefilterte DocIDs für Query 1329 (nur Zahl): ['1703509', '1696184']
# Gefilterte DocIDs für Query 1330 (nur Zahl): ['2920794', '1680090', '1707867']
# Gefilterte DocIDs für Query 1332 (nur Zahl): ['8509', '1672372', '1681715', '1706975', '21483']
# Gefilterte DocIDs für Query 1333 (nur Zahl): ['1683662']
# Gefilterte DocIDs für Query 1335 (nur Zahl): ['27972']
# Gefilterte DocIDs für Query 1336 (nur Zahl): ['1679891', '1707170']
# Gefilterte DocIDs für Query 1338 (nur Zahl): ['8509']
# Gefilterte DocIDs für Query 1339 (nur Zahl): ['713']
# Gefilterte DocIDs für Query 1342 (nur Zahl): ['1704336']
# Gefilterte DocIDs für Query 1349 (nur Zahl): ['901']
# Gefilterte DocIDs für Query 1350 (nur Zahl): []
# Gefilterte DocIDs für Query 1352 (nur Zahl): ['20723']
# Gefilterte DocIDs für Query 1357 (nur Zahl): ['8897']
# Gefilterte DocIDs für Query 1359 (nur Zahl): ['27950']
# Gefilterte DocIDs für Query 1361 (nur Zahl): ['25727']
# Gefilterte DocIDs für Query 1362 (nur Zahl): ['2863453']
# Gefilterte DocIDs für Query 1366 (nur Zahl): ['1690294', '2902312', '1672966', '1694006', '3351007']
# Gefilterte DocIDs für Query 1367 (nur Zahl): ['1702220', '25986']
# Gefilterte DocIDs für Query 1374 (nur Zahl): []
# Gefilterte DocIDs für Query 1377 (nur Zahl): []
# Gefilterte DocIDs für Query 1378 (nur Zahl): []
# Gefilterte DocIDs für Query 1388 (nur Zahl): ['1685715']
# Gefilterte DocIDs für Query 1391 (nur Zahl): []
# Gefilterte DocIDs für Query 1392 (nur Zahl): ['2910093']
# Gefilterte DocIDs für Query 1394 (nur Zahl): ['864']
# Gefilterte DocIDs für Query 1396 (nur Zahl): ['2876127']
# Gefilterte DocIDs für Query 1398 (nur Zahl): ['3360925']
# Gefilterte DocIDs für Query 1399 (nur Zahl): ['1706720', '1697268', '17381']
# Gefilterte DocIDs für Query 1406 (nur Zahl): ['1672484']
# Gefilterte DocIDs für Query 1407 (nur Zahl): ['1616581']
# Gefilterte DocIDs für Query 1412 (nur Zahl): []
# Gefilterte DocIDs für Query 1418 (nur Zahl): ['12609', '1402']
# Gefilterte DocIDs für Query 1419 (nur Zahl): ['12609', '1597472']
# Gefilterte DocIDs für Query 1420 (nur Zahl): ['28346']
# Gefilterte DocIDs für Query 1421 (nur Zahl): []
# Gefilterte DocIDs für Query 1433 (nur Zahl): ['21012']
# Gefilterte DocIDs für Query 1436 (nur Zahl): ['7141', '13844']
# Gefilterte DocIDs für Query 1444 (nur Zahl): ['3347160']
# Gefilterte DocIDs für Query 1450 (nur Zahl): ['24196']
# Gefilterte DocIDs für Query 1452 (nur Zahl): ['1595360']
# Gefilterte DocIDs für Query 1454 (nur Zahl): ['7429']
# Gefilterte DocIDs für Query 1456 (nur Zahl): ['1697289']
# Gefilterte DocIDs für Query 1461 (nur Zahl): ['19005', '8499']
# Gefilterte DocIDs für Query 1464 (nur Zahl): ['1703963']
# Gefilterte DocIDs für Query 1466 (nur Zahl): ['9195', '1645910']
# Gefilterte DocIDs für Query 1468 (nur Zahl): []
# Gefilterte DocIDs für Query 1475 (nur Zahl): ['1686365']
# Gefilterte DocIDs für Query 1481 (nur Zahl): ['1698140']
# Gefilterte DocIDs für Query 1489 (nur Zahl): ['18413']
# Gefilterte DocIDs für Query 1494 (nur Zahl): ['21490', '24496', '7062', '26317', '29147']
# Gefilterte DocIDs für Query 1496 (nur Zahl): []
# Gefilterte DocIDs für Query 1498 (nur Zahl): ['3364753']
# Gefilterte DocIDs für Query 1500 (nur Zahl): []
# Gefilterte DocIDs für Query 1504 (nur Zahl): ['27455']
# Gefilterte DocIDs für Query 1509 (nur Zahl): ['1769']
# Gefilterte DocIDs für Query 1514 (nur Zahl): ['1598158']
# Gefilterte DocIDs für Query 1515 (nur Zahl): ['2869443']
# Gefilterte DocIDs für Query 1518 (nur Zahl): ['1769']
# Gefilterte DocIDs für Query 1522 (nur Zahl): ['1672098']
# Gefilterte DocIDs für Query 1523 (nur Zahl): ['2470']
# Gefilterte DocIDs für Query 1524 (nur Zahl): ['22767', '28389']
# Gefilterte DocIDs für Query 1525 (nur Zahl): ['17381', '15186', '1402']
# Gefilterte DocIDs für Query 1529 (nur Zahl): []
# Gefilterte DocIDs für Query 1533 (nur Zahl): ['11956']
# Gefilterte DocIDs für Query 1534 (nur Zahl): ['3352042', '2910709', '8048']
# Gefilterte DocIDs für Query 1536 (nur Zahl): ['1936']
# Gefilterte DocIDs für Query 1539 (nur Zahl): ['1690946', '1692383']
# Gefilterte DocIDs für Query 1540 (nur Zahl): ['1481']
# Gefilterte DocIDs für Query 1541 (nur Zahl): ['8536']
# Gefilterte DocIDs für Query 1542 (nur Zahl): ['1646074', '8298']
# Gefilterte DocIDs für Query 1543 (nur Zahl): ['1682589']
# Gefilterte DocIDs für Query 1546 (nur Zahl): ['10078', '15875']
# Gefilterte DocIDs für Query 1548 (nur Zahl): ['22627', '26639']
# Gefilterte DocIDs für Query 1549 (nur Zahl): ['26639']
# Gefilterte DocIDs für Query 1553 (nur Zahl): ['2917559', '26795']
# Gefilterte DocIDs für Query 1555 (nur Zahl): ['28363']
# Gefilterte DocIDs für Query 1556 (nur Zahl): ['1645460']
# Gefilterte DocIDs für Query 1559 (nur Zahl): ['28861']
# Gefilterte DocIDs für Query 1560 (nur Zahl): ['1700718']
# Gefilterte DocIDs für Query 1564 (nur Zahl): ['1612356', '2867732']
# Gefilterte DocIDs für Query 1565 (nur Zahl): []
# Gefilterte DocIDs für Query 1570 (nur Zahl): ['1704555']
# Gefilterte DocIDs für Query 1572 (nur Zahl): ['10235', '454']
# Gefilterte DocIDs für Query 1573 (nur Zahl): ['21336']
# Gefilterte DocIDs für Query 1578 (nur Zahl): ['1694966']
# Gefilterte DocIDs für Query 1579 (nur Zahl): ['1671874']
# Gefilterte DocIDs für Query 1582 (nur Zahl): ['9929']
# Gefilterte DocIDs für Query 1587 (nur Zahl): ['3362951']
# Gefilterte DocIDs für Query 1590 (nur Zahl): ['1701799']
# Gefilterte DocIDs für Query 1594 (nur Zahl): ['21159']
# Gefilterte DocIDs für Query 1595 (nur Zahl): ['713']
# Gefilterte DocIDs für Query 1599 (nur Zahl): ['8627']
# Gefilterte DocIDs für Query 1601 (nur Zahl): []
# Gefilterte DocIDs für Query 1602 (nur Zahl): []
# Gefilterte DocIDs für Query 1603 (nur Zahl): []
# Gefilterte DocIDs für Query 1605 (nur Zahl): ['26917']
# Gefilterte DocIDs für Query 1607 (nur Zahl): ['22426']
# Gefilterte DocIDs für Query 1608 (nur Zahl): ['3357506']
# Gefilterte DocIDs für Query 1611 (nur Zahl): ['1640893', '1644275']
# Gefilterte DocIDs für Query 1612 (nur Zahl): ['23763']
# Gefilterte DocIDs für Query 1613 (nur Zahl): ['11186']
# Gefilterte DocIDs für Query 1615 (nur Zahl): ['14264']
# Gefilterte DocIDs für Query 1616 (nur Zahl): ['2866587']
# Gefilterte DocIDs für Query 1619 (nur Zahl): ['1358']
# Gefilterte DocIDs für Query 1627 (nur Zahl): ['7151']
# Gefilterte DocIDs für Query 1629 (nur Zahl): ['29132']
# Gefilterte DocIDs für Query 1630 (nur Zahl): ['26917']
# Gefilterte DocIDs für Query 1633 (nur Zahl): ['8604']
# Gefilterte DocIDs für Query 1635 (nur Zahl): ['2871755', '8604']
# Gefilterte DocIDs für Query 1636 (nur Zahl): []
# Gefilterte DocIDs für Query 1637 (nur Zahl): ['1535', '8591']
# Gefilterte DocIDs für Query 1639 (nur Zahl): ['2860903']
# Gefilterte DocIDs für Query 1640 (nur Zahl): ['1535', '8591', '11868']
# Gefilterte DocIDs für Query 1641 (nur Zahl): ['2862314']
# Gefilterte DocIDs für Query 1647 (nur Zahl): ['2918989']
# Gefilterte DocIDs für Query 1649 (nur Zahl): ['9229']
# Gefilterte DocIDs für Query 1652 (nur Zahl): ['1671498']
# Gefilterte DocIDs für Query 1653 (nur Zahl): []
# Gefilterte DocIDs für Query 1655 (nur Zahl): ['10877']
# Gefilterte DocIDs für Query 1656 (nur Zahl): ['25992']
# Gefilterte DocIDs für Query 1657 (nur Zahl): ['2862120', '1670666', '2862165', '1644447']
# Gefilterte DocIDs für Query 1659 (nur Zahl): ['22426']
# Gefilterte DocIDs für Query 1660 (nur Zahl): ['1677513']
# Gefilterte DocIDs für Query 1667 (nur Zahl): ['1614276']
# Gefilterte DocIDs für Query 1669 (nur Zahl): ['2901408', '10229']
# Gefilterte DocIDs für Query 1672 (nur Zahl): ['1698185']
# Gefilterte DocIDs für Query 1674 (nur Zahl): ['16849', '17803', '15856', '13864', '13897']
# Gefilterte DocIDs für Query 1676 (nur Zahl): ['1645679']
# Gefilterte DocIDs für Query 1677 (nur Zahl): ['6643']
# Gefilterte DocIDs für Query 1678 (nur Zahl): ['1644970', '19597']
# Gefilterte DocIDs für Query 1679 (nur Zahl): ['3347047', '1642795']
# Gefilterte DocIDs für Query 1682 (nur Zahl): ['22874', '2921842']
# Gefilterte DocIDs für Query 1688 (nur Zahl): ['2902115', '28030', '26109']
# Gefilterte DocIDs für Query 1690 (nur Zahl): ['1670937']
# Gefilterte DocIDs für Query 1692 (nur Zahl): ['14340', '1074']
# Gefilterte DocIDs für Query 1693 (nur Zahl): ['5195']
# Gefilterte DocIDs für Query 1694 (nur Zahl): ['26106']
# Gefilterte DocIDs für Query 1700 (nur Zahl): ['14116', '7182']
# Gefilterte DocIDs für Query 1702 (nur Zahl): ['18390']
# Gefilterte DocIDs für Query 1707 (nur Zahl): ['27155', '1689439']
# Gefilterte DocIDs für Query 1710 (nur Zahl): []
# Gefilterte DocIDs für Query 1712 (nur Zahl): ['19958']
# Gefilterte DocIDs für Query 1716 (nur Zahl): ['3264']
# Gefilterte DocIDs für Query 1717 (nur Zahl): ['9482']
# Gefilterte DocIDs für Query 1718 (nur Zahl): ['979917', '1687471']
# Gefilterte DocIDs für Query 1722 (nur Zahl): ['6807', '15154', '19860', '5751']
# Gefilterte DocIDs für Query 1725 (nur Zahl): []
# Gefilterte DocIDs für Query 1726 (nur Zahl): ['8750']
# Gefilterte DocIDs für Query 1728 (nur Zahl): ['1033']
# Gefilterte DocIDs für Query 1730 (nur Zahl): []
# Gefilterte DocIDs für Query 1732 (nur Zahl): []
# Gefilterte DocIDs für Query 1734 (nur Zahl): []
# Gefilterte DocIDs für Query 1735 (nur Zahl): []
# Gefilterte DocIDs für Query 1740 (nur Zahl): ['1641627']
# Gefilterte DocIDs für Query 1742 (nur Zahl): ['13172']
# Gefilterte DocIDs für Query 1743 (nur Zahl): ['25130']
# Gefilterte DocIDs für Query 1744 (nur Zahl): []
# Gefilterte DocIDs für Query 1745 (nur Zahl): ['1700403']
# Gefilterte DocIDs für Query 1749 (nur Zahl): ['14752']
# Gefilterte DocIDs für Query 1750 (nur Zahl): ['19321', '1640991']
# Gefilterte DocIDs für Query 1751 (nur Zahl): ['13999']
# Gefilterte DocIDs für Query 1753 (nur Zahl): []
# Gefilterte DocIDs für Query 1756 (nur Zahl): []
# Gefilterte DocIDs für Query 1757 (nur Zahl): ['21461']
# Gefilterte DocIDs für Query 1758 (nur Zahl): ['1705229']
# Gefilterte DocIDs für Query 1760 (nur Zahl): ['1696892', '4034', '17331', '1679062']
# Gefilterte DocIDs für Query 1761 (nur Zahl): ['27429', '14813']
# Gefilterte DocIDs für Query 1762 (nur Zahl): ['1593798']
# Gefilterte DocIDs für Query 1763 (nur Zahl): ['19262']
# Gefilterte DocIDs für Query 1766 (nur Zahl): ['1682589', '1410']
# Gefilterte DocIDs für Query 1768 (nur Zahl): ['1690492']
# Gefilterte DocIDs für Query 1770 (nur Zahl): ['2877106']
# Gefilterte DocIDs für Query 1772 (nur Zahl): ['1690042', '1677688', '1675681']
# Gefilterte DocIDs für Query 1773 (nur Zahl): ['2871774']
# Gefilterte DocIDs für Query 1774 (nur Zahl): ['6197', '24678', '5282']
# Gefilterte DocIDs für Query 1775 (nur Zahl): ['24678']
# Gefilterte DocIDs für Query 1779 (nur Zahl): ['10376', '1612631', '677']
# Gefilterte DocIDs für Query 1782 (nur Zahl): ['1378798']
# Gefilterte DocIDs für Query 1783 (nur Zahl): ['9626']
# Gefilterte DocIDs für Query 1784 (nur Zahl): ['1616227']
# Gefilterte DocIDs für Query 1785 (nur Zahl): ['26700', '13040']
# Gefilterte DocIDs für Query 1786 (nur Zahl): []
# Gefilterte DocIDs für Query 1790 (nur Zahl): ['1641614']
# Gefilterte DocIDs für Query 1791 (nur Zahl): ['1676289']
# Gefilterte DocIDs für Query 1792 (nur Zahl): ['11766']
# Gefilterte DocIDs für Query 1795 (nur Zahl): ['1695066']
# Gefilterte DocIDs für Query 1796 (nur Zahl): ['2866283', '2867584']
# Gefilterte DocIDs für Query 1802 (nur Zahl): ['1692095']
# Gefilterte DocIDs für Query 1804 (nur Zahl): ['26507']
# Gefilterte DocIDs für Query 1808 (nur Zahl): ['1688072']
# Gefilterte DocIDs für Query 1811 (nur Zahl): ['28428']
# Gefilterte DocIDs für Query 1813 (nur Zahl): ['23078']
# Gefilterte DocIDs für Query 1814 (nur Zahl): ['2899982']
# Gefilterte DocIDs für Query 1815 (nur Zahl): ['21962']
# Gefilterte DocIDs für Query 1822 (nur Zahl): ['1693572', '1679075']
# Gefilterte DocIDs für Query 1823 (nur Zahl): ['1687327']
# Gefilterte DocIDs für Query 1825 (nur Zahl): ['22699']
# Gefilterte DocIDs für Query 1828 (nur Zahl): ['1699493']
# Gefilterte DocIDs für Query 1832 (nur Zahl): ['25302']
# Gefilterte DocIDs für Query 1835 (nur Zahl): ['14779']
# Gefilterte DocIDs für Query 1840 (nur Zahl): ['11729']
# Gefilterte DocIDs für Query 1841 (nur Zahl): ['19146']
# Gefilterte DocIDs für Query 1844 (nur Zahl): ['1697515']
# Gefilterte DocIDs für Query 1851 (nur Zahl): []
# Gefilterte DocIDs für Query 1855 (nur Zahl): ['1615372']
# Gefilterte DocIDs für Query 1856 (nur Zahl): ['5397']
# Gefilterte DocIDs für Query 1858 (nur Zahl): ['1692275']
# Gefilterte DocIDs für Query 1864 (nur Zahl): ['1596017', '2902199']
# Gefilterte DocIDs für Query 1867 (nur Zahl): ['1701970']
# Gefilterte DocIDs für Query 1871 (nur Zahl): ['9660', '11611', '3112']
# Gefilterte DocIDs für Query 1872 (nur Zahl): []
# Gefilterte DocIDs für Query 1874 (nur Zahl): ['1686417']
# Gefilterte DocIDs für Query 1877 (nur Zahl): ['60']
# Gefilterte DocIDs für Query 1878 (nur Zahl): ['1518']
# Gefilterte DocIDs für Query 1885 (nur Zahl): ['25723']
# Gefilterte DocIDs für Query 1886 (nur Zahl): ['1676575', '3346222']
# Gefilterte DocIDs für Query 1887 (nur Zahl): ['26817']
# Gefilterte DocIDs für Query 1888 (nur Zahl): ['1670092']
# Gefilterte DocIDs für Query 1889 (nur Zahl): ['15832']
# Gefilterte DocIDs für Query 1892 (nur Zahl): ['3175']
# Gefilterte DocIDs für Query 1893 (nur Zahl): ['1700983']
# Gefilterte DocIDs für Query 1895 (nur Zahl): ['620', '4200']
# Gefilterte DocIDs für Query 1898 (nur Zahl): ['1596215']
# Gefilterte DocIDs für Query 1900 (nur Zahl): ['1706087']
# Gefilterte DocIDs für Query 1902 (nur Zahl): ['3862']
# Gefilterte DocIDs für Query 1903 (nur Zahl): ['14186']
# Gefilterte DocIDs für Query 1905 (nur Zahl): ['27870']
# Gefilterte DocIDs für Query 1906 (nur Zahl): ['3387060', '1681056']
# Gefilterte DocIDs für Query 1909 (nur Zahl): ['17763']
# Gefilterte DocIDs für Query 1910 (nur Zahl): ['1504', '27472']
# Gefilterte DocIDs für Query 1911 (nur Zahl): ['1696076']
# Gefilterte DocIDs für Query 1913 (nur Zahl): ['18092']
# Gefilterte DocIDs für Query 1916 (nur Zahl): ['20840']
# Gefilterte DocIDs für Query 1924 (nur Zahl): ['2410']
# Gefilterte DocIDs für Query 1925 (nur Zahl): ['1688503', '1678875']
# Gefilterte DocIDs für Query 1926 (nur Zahl): ['1614843']
# Gefilterte DocIDs für Query 1927 (nur Zahl): ['1683310']
# Gefilterte DocIDs für Query 1933 (nur Zahl): ['1698249']
# Gefilterte DocIDs für Query 1934 (nur Zahl): ['1682826']
# Gefilterte DocIDs für Query 1936 (nur Zahl): ['10607']
# Gefilterte DocIDs für Query 1941 (nur Zahl): ['1685379']
# Gefilterte DocIDs für Query 1949 (nur Zahl): ['21994']
# Gefilterte DocIDs für Query 1955 (nur Zahl): ['7496']
# Gefilterte DocIDs für Query 1956 (nur Zahl): []
# Gefilterte DocIDs für Query 1958 (nur Zahl): ['7496']
# Gefilterte DocIDs für Query 1959 (nur Zahl): ['1615973']
# Gefilterte DocIDs für Query 1960 (nur Zahl): ['6780']
# Gefilterte DocIDs für Query 1961 (nur Zahl): ['19445']
# Gefilterte DocIDs für Query 1963 (nur Zahl): ['18043']
# Gefilterte DocIDs für Query 1968 (nur Zahl): []
# Gefilterte DocIDs für Query 1972 (nur Zahl): ['7496']
# Gefilterte DocIDs für Query 1974 (nur Zahl): ['1616705', '1610825']
# Gefilterte DocIDs für Query 1975 (nur Zahl): ['13725']
# Gefilterte DocIDs für Query 1977 (nur Zahl): ['1860']
# Gefilterte DocIDs für Query 1978 (nur Zahl): ['2898730']
# Gefilterte DocIDs für Query 1980 (nur Zahl): ['1681753']
# Gefilterte DocIDs für Query 1985 (nur Zahl): ['1670479']
# Gefilterte DocIDs für Query 1988 (nur Zahl): []
# Gefilterte DocIDs für Query 1989 (nur Zahl): ['1679416']
# Gefilterte DocIDs für Query 1991 (nur Zahl): ['1671303']
# Gefilterte DocIDs für Query 1993 (nur Zahl): ['1684101']
# Gefilterte DocIDs für Query 1997 (nur Zahl): ['1680311']
# Gefilterte DocIDs für Query 1998 (nur Zahl): []
# Gefilterte DocIDs für Query 2000 (nur Zahl): ['2910587']
# Gefilterte DocIDs für Query 2001 (nur Zahl): ['1596741']
# Gefilterte DocIDs für Query 2002 (nur Zahl): ['1680311']
# Gefilterte DocIDs für Query 2004 (nur Zahl): ['16062', '26204']
# Gefilterte DocIDs für Query 2009 (nur Zahl): ['16725']
# Gefilterte DocIDs für Query 2011 (nur Zahl): ['12423', '3639', '26520']
# Gefilterte DocIDs für Query 2012 (nur Zahl): ['1590359']
# Gefilterte DocIDs für Query 2013 (nur Zahl): ['9935']
# Gefilterte DocIDs für Query 2014 (nur Zahl): ['21217', '23452']
# Gefilterte DocIDs für Query 2015 (nur Zahl): ['16672']
# Gefilterte DocIDs für Query 2017 (nur Zahl): ['1190']
# Gefilterte DocIDs für Query 2018 (nur Zahl): ['1645970']
# Gefilterte DocIDs für Query 2021 (nur Zahl): ['7652']
# Gefilterte DocIDs für Query 2022 (nur Zahl): ['1485', '29199']
# Gefilterte DocIDs für Query 2023 (nur Zahl): ['2877973', '3251', '1682336', '20781', '3391182', '1673331', '13069', '639', '14465']
# Gefilterte DocIDs für Query 2028 (nur Zahl): ['1611941', '5709', '10263']
# Gefilterte DocIDs für Query 2030 (nur Zahl): ['8362']
# Gefilterte DocIDs für Query 2033 (nur Zahl): []
# Gefilterte DocIDs für Query 2034 (nur Zahl): ['2895']
# Gefilterte DocIDs für Query 2040 (nur Zahl): ['22297']
# Gefilterte DocIDs für Query 2042 (nur Zahl): ['1688623']
# Gefilterte DocIDs für Query 2043 (nur Zahl): ['27499', '19256']
# Gefilterte DocIDs für Query 2045 (nur Zahl): ['24124']
# Gefilterte DocIDs für Query 2046 (nur Zahl): ['15651']
# Gefilterte DocIDs für Query 2047 (nur Zahl): ['19892']
# Gefilterte DocIDs für Query 2048 (nur Zahl): ['1677407']
# Gefilterte DocIDs für Query 2055 (nur Zahl): ['2908454', '1705057', '3359531']
# Gefilterte DocIDs für Query 2056 (nur Zahl): []
# Gefilterte DocIDs für Query 2064 (nur Zahl): ['1684460', '2909151']
# Gefilterte DocIDs für Query 2069 (nur Zahl): ['1701548']
# Gefilterte DocIDs für Query 2072 (nur Zahl): []
# Gefilterte DocIDs für Query 2075 (nur Zahl): ['22141']
# Gefilterte DocIDs für Query 2079 (nur Zahl): ['23266']
# Gefilterte DocIDs für Query 2080 (nur Zahl): []
# Gefilterte DocIDs für Query 2081 (nur Zahl): []
# Gefilterte DocIDs für Query 2083 (nur Zahl): []
# Gefilterte DocIDs für Query 2086 (nur Zahl): ['19376']
# Gefilterte DocIDs für Query 2087 (nur Zahl): ['2876220']
# ...
# Gefilterte DocIDs für Query 56754 (nur Zahl): ['14191', '23717']
# Gefilterte DocIDs für Query 56755 (nur Zahl): ['8021']
# Gefilterte DocIDs für Query 56757 (nur Zahl): ['3355361']
# Gefilterte DocIDs für Query 56758 (nur Zahl): ['3386097']
# Gefilterte DocIDs für Query 56759 (nur Zahl): ['15875']
# Gefilterte DocIDs für Query 56760 (nur Zahl): []
# Gefilterte DocIDs für Query 56762 (nur Zahl): ['1656']
# Gefilterte DocIDs für Query 56763 (nur Zahl): ['2014']
# Gefilterte DocIDs für Query 56764 (nur Zahl): ['23236']
# Gefilterte DocIDs für Query 56765 (nur Zahl): []
# Gefilterte DocIDs für Query 56766 (nur Zahl): ['20896']
# Gefilterte DocIDs für Query 56768 (nur Zahl): ['3397978']
# Gefilterte DocIDs für Query 56769 (nur Zahl): ['1643268']
# Gefilterte DocIDs für Query 56772 (nur Zahl): ['1591604', '1706986']
# Gefilterte DocIDs für Query 56773 (nur Zahl): ['6618']
# Gefilterte DocIDs für Query 56774 (nur Zahl): []
# Gefilterte DocIDs für Query 56778 (nur Zahl): ['391']
# Gefilterte DocIDs für Query 56779 (nur Zahl): ['15128']
# Gefilterte DocIDs für Query 56780 (nur Zahl): ['1700557']
# Gefilterte DocIDs für Query 56781 (nur Zahl): ['1698399']
# Gefilterte DocIDs für Query 56783 (nur Zahl): ['25560']
# Gefilterte DocIDs für Query 56784 (nur Zahl): []
# Gefilterte DocIDs für Query 56785 (nur Zahl): ['3351344']
# Gefilterte DocIDs für Query 56786 (nur Zahl): []
# Gefilterte DocIDs für Query 56787 (nur Zahl): ['1691565']
# Gefilterte DocIDs für Query 56788 (nur Zahl): ['1006', '3399706']
# Gefilterte DocIDs für Query 56789 (nur Zahl): ['3011']
# Gefilterte DocIDs für Query 56790 (nur Zahl): []
# Gefilterte DocIDs für Query 56791 (nur Zahl): []
# Gefilterte DocIDs für Query 56794 (nur Zahl): ['2861945']
# Gefilterte DocIDs für Query 56795 (nur Zahl): []
# Gefilterte DocIDs für Query 56796 (nur Zahl): ['1687988', '28207']
# Gefilterte DocIDs für Query 56798 (nur Zahl): ['10318']
# Gefilterte DocIDs für Query 56799 (nur Zahl): ['10318']
# Gefilterte DocIDs für Query 56800 (nur Zahl): ['3348528']
# Gefilterte DocIDs für Query 56801 (nur Zahl): []
# Gefilterte DocIDs für Query 73723 (nur Zahl): []
# Gefilterte DocIDs für Query 73729 (nur Zahl): ['3147']
# Gefilterte DocIDs für Query 73730 (nur Zahl): ['331']
# Gefilterte DocIDs für Query 73732 (nur Zahl): ['21153']
# Gefilterte DocIDs für Query 73751 (nur Zahl): ['1641599']
# Gefilterte DocIDs für Query 73753 (nur Zahl): ['21216']
# Gefilterte DocIDs für Query 73758 (nur Zahl): ['21153']
# Gefilterte DocIDs für Query 73772 (nur Zahl): ['1696150']
# Gefilterte DocIDs für Query 73780 (nur Zahl): ['1687297']
# Gefilterte DocIDs für Query 73781 (nur Zahl): ['1609954']
# Gefilterte DocIDs für Query 73791 (nur Zahl): ['25825']
# Gefilterte DocIDs für Query 73794 (nur Zahl): ['1641438', '753']
# Gefilterte DocIDs für Query 73796 (nur Zahl): ['17019']
# Gefilterte DocIDs für Query 73809 (nur Zahl): ['7587']
# Gefilterte DocIDs für Query 73810 (nur Zahl): ['1678975', '1691726', '1677440']
# Gefilterte DocIDs für Query 73850 (nur Zahl): ['1644165', '2908382', '3432531', '21504']
# Gefilterte DocIDs für Query 73857 (nur Zahl): ['1697129', '1680353', '1697152']
# Gefilterte DocIDs für Query 73860 (nur Zahl): ['1682265']
# Gefilterte DocIDs für Query 73861 (nur Zahl): ['17372', '1610418']
# Gefilterte DocIDs für Query 73866 (nur Zahl): ['1504']
# Gefilterte DocIDs für Query 73873 (nur Zahl): ['1641599']
# Gefilterte DocIDs für Query 73919 (nur Zahl): ['2921296']
# Gefilterte DocIDs für Query 73925 (nur Zahl): ['5755', '11623']
# Gefilterte DocIDs für Query 73938 (nur Zahl): []
# Gefilterte DocIDs für Query 73941 (nur Zahl): ['1596883']
# Gefilterte DocIDs für Query 73942 (nur Zahl): ['1689790']
# Gefilterte DocIDs für Query 73943 (nur Zahl): ['1673951', '24955']
# Gefilterte DocIDs für Query 73944 (nur Zahl): ['1674995', '1682361']
# Gefilterte DocIDs für Query 73945 (nur Zahl): ['20089', '7002', '1616913']
# Gefilterte DocIDs für Query 73967 (nur Zahl): ['1644761', '20089']
# Gefilterte DocIDs für Query 73972 (nur Zahl): ['23615']
# Gefilterte DocIDs für Query 73974 (nur Zahl): ['2914050']
# Gefilterte DocIDs für Query 73978 (nur Zahl): ['1594624']
# Gefilterte DocIDs für Query 73995 (nur Zahl): ['23204']
# Gefilterte DocIDs für Query 74006 (nur Zahl): ['1694147', '1698293']
# Gefilterte DocIDs für Query 74008 (nur Zahl): ['1641229']
# Gefilterte DocIDs für Query 74013 (nur Zahl): ['1702666']
# Gefilterte DocIDs für Query 74016 (nur Zahl): []
# Gefilterte DocIDs für Query 74028 (nur Zahl): ['25371', '24179', '2899446']
# Gefilterte DocIDs für Query 74044 (nur Zahl): ['12512']
# Gefilterte DocIDs für Query 74060 (nur Zahl): ['1698042', '2863960']
# Gefilterte DocIDs für Query 74101 (nur Zahl): ['1683772']
# Gefilterte DocIDs für Query 74120 (nur Zahl): ['2913552']
# Gefilterte DocIDs für Query 74125 (nur Zahl): ['12433']
# Gefilterte DocIDs für Query 74130 (nur Zahl): []
# Gefilterte DocIDs für Query 74142 (nur Zahl): []
# Gefilterte DocIDs für Query 74149 (nur Zahl): ['1704657', '21520']
# Gefilterte DocIDs für Query 74168 (nur Zahl): ['1594624', '465']
# Gefilterte DocIDs für Query 74175 (nur Zahl): ['1596741']
# Gefilterte DocIDs für Query 74176 (nur Zahl): ['770']
# Gefilterte DocIDs für Query 74178 (nur Zahl): []
# Gefilterte DocIDs für Query 74182 (nur Zahl): []
# Gefilterte DocIDs für Query 74184 (nur Zahl): ['1595015']
# Gefilterte DocIDs für Query 74185 (nur Zahl): ['2021629', '1597280']
# Gefilterte DocIDs für Query 74186 (nur Zahl): []
# Gefilterte DocIDs für Query 74187 (nur Zahl): ['3343766']
# Gefilterte DocIDs für Query 74189 (nur Zahl): ['7066']
# Gefilterte DocIDs für Query 74191 (nur Zahl): ['1690206']
# Gefilterte DocIDs für Query 74192 (nur Zahl): ['2896235']
# Gefilterte DocIDs für Query 74194 (nur Zahl): ['7024']
# Gefilterte DocIDs für Query 74195 (nur Zahl): []
# Gefilterte DocIDs für Query 74196 (nur Zahl): ['3360422']
# Gefilterte DocIDs für Query 74197 (nur Zahl): ['1504']
# Gefilterte DocIDs für Query 74198 (nur Zahl): []
# Gefilterte DocIDs für Query 74199 (nur Zahl): []
# Gefilterte DocIDs für Query 74445 (nur Zahl): ['1040', '1699071', '3420']
# Gefilterte DocIDs für Query 74447 (nur Zahl): ['19724', '25743', '11291']
# Gefilterte DocIDs für Query 74448 (nur Zahl): ['7429', '14978', '8954']
# Gefilterte DocIDs für Query 74449 (nur Zahl): ['1645072', '1645350', '15792', '11728']
# Gefilterte DocIDs für Query 74453 (nur Zahl): ['2471', '15385', '11858', '3790', '5858', '2871044']
# Gefilterte DocIDs für Query 74454 (nur Zahl): ['27926', '8612', '27905']
# Gefilterte DocIDs für Query 74456 (nur Zahl): ['834', '7448', '7429']
# Gefilterte DocIDs für Query 74459 (nur Zahl): ['18927', '2859']
# Gefilterte DocIDs für Query 74461 (nur Zahl): []
# Gefilterte DocIDs für Query 74465 (nur Zahl): ['1597248']
# Gefilterte DocIDs für Query 74468 (nur Zahl): []
# Gefilterte DocIDs für Query 74474 (nur Zahl): ['1702754', '1672632']
# Gefilterte DocIDs für Query 74475 (nur Zahl): ['17381', '27472']
# Gefilterte DocIDs für Query 74478 (nur Zahl): ['10521']
# Gefilterte DocIDs für Query 74479 (nur Zahl): ['27472', '22318', '17381']
# Gefilterte DocIDs für Query 74482 (nur Zahl): ['1609798']
# Gefilterte DocIDs für Query 74487 (nur Zahl): ['2021798']
# Gefilterte DocIDs für Query 74488 (nur Zahl): ['8612']
# Gefilterte DocIDs für Query 74493 (nur Zahl): ['21284']
# Gefilterte DocIDs für Query 74495 (nur Zahl): ['7752']
# Gefilterte DocIDs für Query 74497 (nur Zahl): ['16943', '20164', '27002']
# Gefilterte DocIDs für Query 74498 (nur Zahl): ['26198']
# Gefilterte DocIDs für Query 74499 (nur Zahl): ['8612']
# Gefilterte DocIDs für Query 74502 (nur Zahl): ['713']
# Gefilterte DocIDs für Query 74504 (nur Zahl): ['14978', '8954']
# Gefilterte DocIDs für Query 74510 (nur Zahl): ['15913']
# Gefilterte DocIDs für Query 74512 (nur Zahl): ['679']
# Gefilterte DocIDs für Query 74515 (nur Zahl): ['15490']
# Gefilterte DocIDs für Query 74524 (nur Zahl): ['1381']
# Gefilterte DocIDs für Query 74525 (nur Zahl): ['9483']
# Gefilterte DocIDs für Query 74526 (nur Zahl): ['21284']
# Gefilterte DocIDs für Query 74527 (nur Zahl): ['13587']
# Gefilterte DocIDs für Query 74528 (nur Zahl): ['26198']
# Gefilterte DocIDs für Query 74530 (nur Zahl): ['21778', '10771']
# Gefilterte DocIDs für Query 74531 (nur Zahl): ['2921962']
# Gefilterte DocIDs für Query 74534 (nur Zahl): ['29234']
# Gefilterte DocIDs für Query 74535 (nur Zahl): ['25867', '29147', '7062', '21490', '24496']
# Gefilterte DocIDs für Query 74541 (nur Zahl): ['17000']
# Gefilterte DocIDs für Query 74542 (nur Zahl): ['11142']
# Gefilterte DocIDs für Query 74549 (nur Zahl): ['23010', '10189']
# Gefilterte DocIDs für Query 74552 (nur Zahl): ['21284']
# Gefilterte DocIDs für Query 74553 (nur Zahl): ['10342', '22130', '13219']
# Gefilterte DocIDs für Query 74557 (nur Zahl): ['7429']
# Gefilterte DocIDs für Query 74558 (nur Zahl): ['208']
# Gefilterte DocIDs für Query 74560 (nur Zahl): ['1616494']
# Gefilterte DocIDs für Query 74562 (nur Zahl): ['1674464']
# Gefilterte DocIDs für Query 74563 (nur Zahl): ['2902001', '18927']
# Gefilterte DocIDs für Query 74564 (nur Zahl): []
# Gefilterte DocIDs für Query 74568 (nur Zahl): []
# Gefilterte DocIDs für Query 74569 (nur Zahl): []
# Gefilterte DocIDs für Query 74570 (nur Zahl): []
# Gefilterte DocIDs für Query 74572 (nur Zahl): ['10598', '20758']
# Gefilterte DocIDs für Query 74575 (nur Zahl): ['18477']
# Gefilterte DocIDs für Query 74576 (nur Zahl): []
# Gefilterte DocIDs für Query 74577 (nur Zahl): ['1677243']
# Gefilterte DocIDs für Query 74581 (nur Zahl): ['10521']
# Gefilterte DocIDs für Query 74582 (nur Zahl): ['18221']
# Gefilterte DocIDs für Query 74583 (nur Zahl): ['27249', '12654', '6717']
# Gefilterte DocIDs für Query 74585 (nur Zahl): ['10877']
# Gefilterte DocIDs für Query 74592 (nur Zahl): []
# Gefilterte DocIDs für Query 74594 (nur Zahl): ['1694256']
# Gefilterte DocIDs für Query 74595 (nur Zahl): ['1594654']
# Gefilterte DocIDs für Query 74602 (nur Zahl): ['18221']
# Gefilterte DocIDs für Query 74604 (nur Zahl): ['1698980', '19146']
# Gefilterte DocIDs für Query 74606 (nur Zahl): ['1694075']
# Gefilterte DocIDs für Query 74610 (nur Zahl): ['24802']
# Gefilterte DocIDs für Query 74611 (nur Zahl): ['22368', '9266', '12423']
# Gefilterte DocIDs für Query 74612 (nur Zahl): ['1616705', '1610825']
# Gefilterte DocIDs für Query 74614 (nur Zahl): ['14171']
# Gefilterte DocIDs für Query 74622 (nur Zahl): ['26198']
# Gefilterte DocIDs für Query 74626 (nur Zahl): ['7066']
# Gefilterte DocIDs für Query 74628 (nur Zahl): ['2866936']
# Gefilterte DocIDs für Query 74637 (nur Zahl): ['3423364', '6221', '3385005', '3639']
# Gefilterte DocIDs für Query 74639 (nur Zahl): ['14999', '15875']
# Gefilterte DocIDs für Query 74648 (nur Zahl): ['7259']
# Gefilterte DocIDs für Query 74655 (nur Zahl): ['8954', '7448']
# Gefilterte DocIDs für Query 74656 (nur Zahl): ['7429']
# Gefilterte DocIDs für Query 74663 (nur Zahl): ['7448']
# Gefilterte DocIDs für Query 74664 (nur Zahl): ['9420']
# Gefilterte DocIDs für Query 74670 (nur Zahl): []
# Gefilterte DocIDs für Query 74671 (nur Zahl): []
# Gefilterte DocIDs für Query 74675 (nur Zahl): ['1592417']
# Gefilterte DocIDs für Query 74679 (nur Zahl): ['10078']
# Gefilterte DocIDs für Query 74684 (nur Zahl): ['21284']
# Gefilterte DocIDs für Query 74692 (nur Zahl): ['25086', '1641821']
# Gefilterte DocIDs für Query 74694 (nur Zahl): ['1699305', '1696645']
# Gefilterte DocIDs für Query 74696 (nur Zahl): []
# Gefilterte DocIDs für Query 74698 (nur Zahl): []
# Gefilterte DocIDs für Query 74700 (nur Zahl): ['17697']
# Gefilterte DocIDs für Query 74703 (nur Zahl): ['1640892']
# Gefilterte DocIDs für Query 74715 (nur Zahl): ['1593851']
# Gefilterte DocIDs für Query 74725 (nur Zahl): []
# Gefilterte DocIDs für Query 74732 (nur Zahl): ['1593052', '3157']
# Gefilterte DocIDs für Query 74746 (nur Zahl): []
# Gefilterte DocIDs für Query 74748 (nur Zahl): ['1698453']
# Gefilterte DocIDs für Query 74753 (nur Zahl): ['16581']
# Gefilterte DocIDs für Query 74755 (nur Zahl): ['1695434']
# Gefilterte DocIDs für Query 74767 (nur Zahl): ['1594704', '9923']
# Gefilterte DocIDs für Query 74772 (nur Zahl): ['1683417']
# Gefilterte DocIDs für Query 74781 (nur Zahl): ['23058']
# Gefilterte DocIDs für Query 74787 (nur Zahl): ['1656']
# Gefilterte DocIDs für Query 74793 (nur Zahl): ['3157']
# Gefilterte DocIDs für Query 74801 (nur Zahl): ['6445']
# Gefilterte DocIDs für Query 74808 (nur Zahl): []
# Gefilterte DocIDs für Query 74829 (nur Zahl): ['25325']
# Gefilterte DocIDs für Query 74868 (nur Zahl): ['2872975', '2866537', '2876128']
# Gefilterte DocIDs für Query 74876 (nur Zahl): ['1645334']
# Gefilterte DocIDs für Query 74884 (nur Zahl): ['1680311']
# Gefilterte DocIDs für Query 74886 (nur Zahl): []
# Gefilterte DocIDs für Query 74891 (nur Zahl): ['3359969']
# Gefilterte DocIDs für Query 74898 (nur Zahl): ['1675037']
# Gefilterte DocIDs für Query 74902 (nur Zahl): []
# Gefilterte DocIDs für Query 74905 (nur Zahl): []
# Gefilterte DocIDs für Query 74912 (nur Zahl): ['1699812']
# Gefilterte DocIDs für Query 74921 (nur Zahl): []
# Gefilterte DocIDs für Query 74925 (nur Zahl): ['19181']
# Gefilterte DocIDs für Query 74927 (nur Zahl): ['685']
# Gefilterte DocIDs für Query 74930 (nur Zahl): ['23058', '2471']
# Gefilterte DocIDs für Query 74932 (nur Zahl): ['1703491']
# Gefilterte DocIDs für Query 74946 (nur Zahl): ['1613522']
# Gefilterte DocIDs für Query 74952 (nur Zahl): ['1705193']
# Gefilterte DocIDs für Query 74955 (nur Zahl): ['15542']
# Gefilterte DocIDs für Query 74957 (nur Zahl): ['1698235']
# Gefilterte DocIDs für Query 74959 (nur Zahl): ['1676441']
# Gefilterte DocIDs für Query 74964 (nur Zahl): ['12379']
# Gefilterte DocIDs für Query 74965 (nur Zahl): []
# Gefilterte DocIDs für Query 74991 (nur Zahl): ['7810', '28975']
# Gefilterte DocIDs für Query 75008 (nur Zahl): ['1701644']
# Gefilterte DocIDs für Query 75025 (nur Zahl): ['1678546', '1701644']
# Gefilterte DocIDs für Query 75029 (nur Zahl): ['2869683']
# Gefilterte DocIDs für Query 75030 (nur Zahl): []
# Gefilterte DocIDs für Query 75034 (nur Zahl): ['2876270']
# Gefilterte DocIDs für Query 75036 (nur Zahl): ['1641821']
# Gefilterte DocIDs für Query 75042 (nur Zahl): []
# Gefilterte DocIDs für Query 75055 (nur Zahl): ['2916966']
# Gefilterte DocIDs für Query 75067 (nur Zahl): ['1696319']
# Gefilterte DocIDs für Query 75068 (nur Zahl): ['1697093']
# Gefilterte DocIDs für Query 75076 (nur Zahl): []
# Gefilterte DocIDs für Query 75077 (nur Zahl): []
# Gefilterte DocIDs für Query 75078 (nur Zahl): ['1612773']
# Gefilterte DocIDs für Query 75079 (nur Zahl): ['3385919', '15600', '3363576']
# Gefilterte DocIDs für Query 75080 (nur Zahl): ['3417352']
# Gefilterte DocIDs für Query 75084 (nur Zahl): []
# Gefilterte DocIDs für Query 75086 (nur Zahl): ['6558']
# Gefilterte DocIDs für Query 75274 (nur Zahl): ['14978']
# Gefilterte DocIDs für Query 75276 (nur Zahl): ['1640582']
# Gefilterte DocIDs für Query 75277 (nur Zahl): ['1706875']
# Gefilterte DocIDs für Query 75282 (nur Zahl): ['12400']
# Gefilterte DocIDs für Query 75283 (nur Zahl): ['12400']
# Gefilterte DocIDs für Query 75287 (nur Zahl): ['1682682', '1706097', '6732', '10659']
# Gefilterte DocIDs für Query 75294 (nur Zahl): ['10376']
# Gefilterte DocIDs für Query 75296 (nur Zahl): ['25274']
# Gefilterte DocIDs für Query 75298 (nur Zahl): ['27472']
# Gefilterte DocIDs für Query 75299 (nur Zahl): ['21284']
# Gefilterte DocIDs für Query 75303 (nur Zahl): ['2914546', '10877', '7783']
# Gefilterte DocIDs für Query 75305 (nur Zahl): ['2957']
# Gefilterte DocIDs für Query 75306 (nur Zahl): ['15875', '14999', '17444', '17667']
# Gefilterte DocIDs für Query 75307 (nur Zahl): ['12392']
# Gefilterte DocIDs für Query 75310 (nur Zahl): ['9555']
# Gefilterte DocIDs für Query 75311 (nur Zahl): ['12400']
# Gefilterte DocIDs für Query 75312 (nur Zahl): ['27098']
# Gefilterte DocIDs für Query 75316 (nur Zahl): ['1673632']
# Gefilterte DocIDs für Query 75319 (nur Zahl): ['1594704', '9923']
# Gefilterte DocIDs für Query 75323 (nur Zahl): ['1594704']
# Gefilterte DocIDs für Query 75333 (nur Zahl): ['713']
# Gefilterte DocIDs für Query 75354 (nur Zahl): []
# Gefilterte DocIDs für Query 75357 (nur Zahl): ['7523']
# Gefilterte DocIDs für Query 75361 (nur Zahl): ['1706892']
# Gefilterte DocIDs für Query 75382 (nur Zahl): ['584', '17223']
# Gefilterte DocIDs für Query 75383 (nur Zahl): ['1675387']
# Gefilterte DocIDs für Query 75384 (nur Zahl): ['27870', '15740']

# %%
# Run File einlesen
run_file = "/home/jovyan/work/datasets/LongEval-Web/runs/longeval-web-fr-2023-04-BM25.gz"
run = pt.io.read_results(run_file)

print(run.head())

# Kopiere die Run-Datei und stelle sicher, dass qid und docno Strings sind
reranked_run = run.copy()
reranked_run['qid'] = reranked_run['qid'].astype(str)
reranked_run['docno'] = reranked_run['docno'].astype(str).str.strip().str.lower()

# Normalisiere auch die Keys und Werte im Dictionary
filtered_query_doc_map = {
    str(qid): [doc.strip().lower() for doc in docs]
    for qid, docs in filtered_query_doc_map.items()
}

# Neue Score-Spalte initialisieren
reranked_run['new_score'] = reranked_run['score']

# Gruppiere die Run-Datei einmal nach qid (für schnelleren Zugriff)
qid_groups = dict(tuple(reranked_run.groupby('qid')))

# Boosting pro Query-ID
for i, (query_id, relevant_docs) in enumerate(filtered_query_doc_map.items()):
    if query_id not in qid_groups:
        continue

    qid_df = qid_groups[query_id]
    boost_mask = qid_df['docno'].isin(relevant_docs)
    boost_indices = qid_df[boost_mask].index

    # Boost anwenden
    if not boost_indices.empty:
        reranked_run.loc[boost_indices, 'new_score'] = reranked_run.loc[boost_indices, 'score'] * 3

# Neue Scores übernehmen
reranked_run['score'] = reranked_run['new_score']
reranked_run = reranked_run.drop(columns=['new_score'])

# Sortieren nach Score und neue Ränge vergeben
reranked_run = reranked_run.sort_values(['qid', 'score'], ascending=[True, False])
reranked_run['rank'] = reranked_run.groupby('qid').cumcount() + 1

# Metadaten hinzufügen
reranked_run['iter'] = 0
reranked_run['name'] = "CIR-longeval-web-fr-2023-04-BM25"

# Spalten in gewünschter Reihenfolge
reranked_run = reranked_run[['qid', 'iter', 'docno', 'rank', 'score', 'name']]

# **Hier Datentypen korrekt setzen vor dem Speichern**
reranked_run['qid'] = reranked_run['qid'].astype(str)
reranked_run['iter'] = reranked_run['iter'].astype(int)
reranked_run['docno'] = reranked_run['docno'].astype(str).str.strip().str.lower()
reranked_run['rank'] = reranked_run['rank'].astype(int)
reranked_run['score'] = reranked_run['score'].astype(float)
reranked_run['name'] = reranked_run['name'].astype(str)

# Vorschau der ersten Zeilen
print(reranked_run.head())

# Speichere das Ergebnis im korrekten TREC-Format ohne Header
reranked_run.to_csv(
    "/home/jovyan/work/datasets/LongEval-Web/index/Gruppe_JMFT/2023-04/reranked_run_jaccard.gz",
    sep='\t',
    index=False,
    header=False,
    compression='gzip'
)
# Out:
#   qid    docno  rank      score       name
# 0   3  2214755     0  24.198403  pyterrier
# 1   3   684186     1  23.318612  pyterrier
# 2   3   637997     2  23.125073  pyterrier
# 3   3   430968     3  22.952865  pyterrier
# 4   3   643034     4  22.752546  pyterrier
#          qid  iter    docno  rank      score                              name
# 509134  1000     0     7496     1  51.884904  CIR-longeval-web-fr-2023-04-BM25
# 508794  1000     0    12254     2  40.162949  CIR-longeval-web-fr-2023-04-BM25
# 508795  1000     0    27513     3  36.520265  CIR-longeval-web-fr-2023-04-BM25
# 508796  1000     0  2912830     4  35.808008  CIR-longeval-web-fr-2023-04-BM25
# 508797  1000     0     6772     5  34.736942  CIR-longeval-web-fr-2023-04-BM25

# %%
#Run File einlesen
run_file = "/home/jovyan/work/datasets/LongEval-Web/runs/longeval-web-fr-2023-04-BM25.gz"
run = pt.io.read_results(run_file)


print(run.head())
# Out:
#   qid    docno  rank      score       name
# 0   3  2214755     0  24.198403  pyterrier
# 1   3   684186     1  23.318612  pyterrier
# 2   3   637997     2  23.125073  pyterrier
# 3   3   430968     3  22.952865  pyterrier
# 4   3   643034     4  22.752546  pyterrier

# %%
# Kopiere die Run-Datei und stelle sicher, dass qid und docno Strings sind
reranked_run = run.copy()
reranked_run['qid'] = reranked_run['qid'].astype(str)
reranked_run['docno'] = reranked_run['docno'].astype(str).str.strip().str.lower()

# Normalisiere auch die Keys und Werte im Dictionary
filtered_query_doc_map = {
    str(qid): [doc.strip().lower() for doc in docs]
    for qid, docs in filtered_query_doc_map.items()
}

# Neue Score-Spalte initialisieren
reranked_run['new_score'] = reranked_run['score']

# Gruppiere die Run-Datei einmal nach qid (für schnelleren Zugriff)
qid_groups = dict(tuple(reranked_run.groupby('qid')))

# Boosting pro Query-ID
for i, (query_id, relevant_docs) in enumerate(filtered_query_doc_map.items()):
    if query_id not in qid_groups:
        continue

    qid_df = qid_groups[query_id]
    boost_mask = qid_df['docno'].isin(relevant_docs)
    boost_indices = qid_df[boost_mask].index

    # Boost anwenden
    if not boost_indices.empty:
        reranked_run.loc[boost_indices, 'new_score'] = reranked_run.loc[boost_indices, 'score'] * 3

# Neue Scores übernehmen
reranked_run['score'] = reranked_run['new_score']
reranked_run = reranked_run.drop(columns=['new_score'])

# Sortieren nach Score und neue Ränge vergeben
reranked_run = reranked_run.sort_values(['qid', 'score'], ascending=[True, False])
reranked_run['rank'] = reranked_run.groupby('qid').cumcount() + 1

# Metadaten hinzufügen
reranked_run['iter'] = 0
reranked_run['name'] = "CIR-longeval-web-fr-2023-04-BM25"

# Spalten in gewünschter Reihenfolge
reranked_run = reranked_run[['qid', 'iter', 'docno', 'rank', 'score', 'name']]

# Vorschau der ersten Zeilen
print(reranked_run.head())
# Out:
#          qid  iter    docno  rank      score                              name
# 509134  1000     0     7496     1  51.884904  CIR-longeval-web-fr-2023-04-BM25
# 508794  1000     0    12254     2  40.162949  CIR-longeval-web-fr-2023-04-BM25
# 508795  1000     0    27513     3  36.520265  CIR-longeval-web-fr-2023-04-BM25
# 508796  1000     0  2912830     4  35.808008  CIR-longeval-web-fr-2023-04-BM25
# 508797  1000     0     6772     5  34.736942  CIR-longeval-web-fr-2023-04-BM25

# %%
# Speichere das Ergebnis im korrekten TREC-Format ohne Header
reranked_run.to_csv("/home/jovyan/work/datasets/LongEval-Web/index/Gruppe_JMFT/2023-04/reranked_run_jaccard.gz", sep='\t', index=False, header=False, compression='gzip')
